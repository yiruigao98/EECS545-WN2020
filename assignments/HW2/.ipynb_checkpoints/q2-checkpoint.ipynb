# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Load data
q2_data = np.load('q2_data/q2_data.npz')

# %%
# Extract training and test sets:
X_train = q2_data['q2x_train']
y_train = q2_data['q2y_train']
X_test = q2_data['q2x_test']
y_test = q2_data['q2y_test']

# %% [markdown]
# Check the classes of y:

# %%
unique_labels = list(set(y_train.flatten().tolist()))
print(unique_labels)
K = len(unique_labels)
print("There are {} classes for the labels.".format(K))
# Out:
# [1.0, 2.0, 3.0]
# There are 3 classes for the labels.

# %% [markdown]
# Now implement the softmax regression from pieces:

# %%
# exponentional:
def exponential(X, w_k):
    return np.exp(X.dot(w_k))


# probability:
def probability(X, w, k):
    exp_list = [exponential(X, w[:,j]) for j in range(K-1)]
    denominator = 1 + np.sum(exp_list)
    if k == K - 1:
        return 1 / denominator
    nominator = exponential(X, w[:,k])
    return nominator / denominator
    
    
# indicator function:
def indicator(y_true, m):
    if y_true == m: 
        return 1
    return 0


# log-likelihood function:
def log_likelihood(X, w, y):
    ll = 0
    for i in range(X.shape[0]):
        for k in range(K):
            if y[i] == unique_labels[k]:
                ll += np.log(probability(X[i,:], w, k))
    return ll
            
    
# gradient:
def gradient(X, w, y, k):
    l = X.shape[0]
    grad = 0
    for i in range(l):
        grad += X[i,:] * (indicator(y[i], unique_labels[k]) - probability(X[i,:], w, k))
    return grad
        

# training：
def training(X, w, y):
    alpha = 0.0005
    epsilon = 1e-10
    ll = 0
    ll_new = 1
    num_iter = 10000
    curr_iter = 0
    while abs(ll - ll_new) > epsilon and curr_iter < num_iter:
        curr_iter += 1
        ll = ll_new
        grad_matrix = np.zeros((w.shape[0], w.shape[1]))
        for k in range(K-1):
            grad_matrix[:,k] = gradient(X, w, y, k)
        print(grad_matrix, grad_matrix.shape)
        w += alpha * grad_matrix
        ll_new = log_likelihood(X, w, y)
        print("The log likelihood at the iteration {} is: {}".format(curr_iter, ll_new))
    print("The final result for the weights are: ", w)
    
        
print(X_train.shape)
w = np.zeros((X_train.shape[1], K - 1))
print(w.shape)
print(log_likelihood(X_train, w, y_train))
training(X_train, w, y_train)
# Out:
# (100, 4)
# (4, 2)
# -109.86122886681082
# [[-29.13333333  19.26666667]
#  [ 10.9         -1.7       ]
#  [-75.36666667  27.43333333]
#  [-30.73333333   7.56666667]] (4, 2)
# The log likelihood at the iteration 1 is: -106.56226014975013
# [[  6.99050168 -10.93643041]
#  [ 28.44222324 -16.39535521]
#  [-49.377401     5.76978296]
#  [-22.18216758   0.44669348]] (4, 2)
# The log likelihood at the iteration 2 is: -104.50613116096254
# [[  9.51961161  -7.52168231]
#  [ 29.16139908 -14.29591546]
#  [-46.42571473   7.25265724]
#  [-21.08225739   0.82525691]] (4, 2)
# The log likelihood at the iteration 3 is: -102.61230680238909
# [[ 11.20357078  -5.39465389]
#  [ 29.4692296  -12.85976862]
#  [-44.0817004    7.89386829]
#  [-20.18261459   0.93662289]] (4, 2)
# The log likelihood at the iteration 4 is: -100.83773934093766
# [[ 12.16187516  -3.94876341]
#  [ 29.42250414 -11.77909271]
#  [-42.256459     8.10027504]
#  [-19.45361284   0.91128166]] (4, 2)
# The log likelihood at the iteration 5 is: -99.16135317232437
# [[ 12.63304987  -2.94585381]
#  [ 29.14011401 -10.93288431]
#  [-40.78505714   8.0313125 ]
#  [-18.84171228   0.8003344 ]] (4, 2)
# The log likelihood at the iteration 6 is: -97.57177184784985
# [[ 12.78606689  -2.2321208 ]
#  [ 28.70710749 -10.24354988]
#  [-39.55244328   7.79118683]
#  [-18.30976752   0.63733612]] (4, 2)
# The log likelihood at the iteration 7 is: -96.06183910007917
# [[ 12.73574562  -1.70734451]
#  [ 28.18181908  -9.66082576]
#  [-38.48159771   7.44846085]
#  [-17.83304161   0.44444493]] (4, 2)
# The log likelihood at the iteration 8 is: -94.62624034851464
# [[ 12.5588108   -1.30652529]
#  [ 27.60358687  -9.15223795]
#  [-37.52180569   7.04787768]
#  [-17.39532845   0.2361531 ]] (4, 2)
# The log likelihood at the iteration 9 is: -93.26049934613371
# [[ 1.23059435e+01 -9.87604326e-01]
#  [ 2.69986218e+01 -8.69678975e+00]
#  [-3.66400291e+01  6.61841896e+00]
#  [-1.69861190e+01  2.18501737e-02]] (4, 2)
# The log likelihood at the iteration 10 is: -91.96056727668876
# [[ 12.01030345  -0.72338895]
#  [ 26.38420391  -8.28085097]
#  [-35.81490609   6.17869431]
#  [-16.59864244  -0.19245123]] (4, 2)
# The log likelihood at the iteration 11 is: -90.72266078941252
# [[ 11.69338057  -0.49629985]
#  [ 25.77159316  -7.89550903]
#  [-35.03269583   5.74050416]
#  [-16.22854941  -0.40296731]] (4, 2)
# The log likelihood at the iteration 12 is: -89.54320155482755
# [[ 11.36894446  -0.29496921]
#  [ 25.16801404  -7.53487015]
#  [-34.28458642   5.3111844 ]
#  [-15.87304358  -0.60738308]] (4, 2)
# The log likelihood at the iteration 13 is: -88.4187952991937
# [[ 11.04568116  -0.11204084]
#  [ 24.57799475  -7.19497206]
#  [-33.56492784   4.89514775]
#  [-15.53031486  -0.80434968]] (4, 2)
# The log likelihood at the iteration 14 is: -87.34622480930908
# [[ 10.7289428    0.0572522 ]
#  [ 24.00426579  -6.87308877]
#  [-32.87008193   4.49489744]
#  [-15.19917333  -0.99315179]] (4, 2)
# The log likelihood at the iteration 15 is: -86.32244680284877
# [[ 10.42190381   0.2160072 ]
#  [ 23.44836157  -6.56728642]
#  [-32.19767877   4.11169464]
#  [-14.87881444  -1.17348732]] (4, 2)
# The log likelihood at the iteration 16 is: -85.3445889418903
# [[ 10.12632332   0.36624645]
#  [ 22.91102269  -6.27613989]
#  [-31.5461387    3.74599818]
#  [-14.56866965  -1.34532131]] (4, 2)
# The log likelihood at the iteration 17 is: -84.40994584255917
# [[  9.84304717   0.50930161]
#  [ 22.39246528  -5.99855223]
#  [-30.91436719   3.39775474]
#  [-14.26831216  -1.5087889 ]] (4, 2)
# The log likelihood at the iteration 18 is: -83.5159739230981
# [[  9.57233804   0.646062  ]
#  [ 21.89256159  -5.73363984]
#  [-30.30156149   3.06659027]
#  [-13.9773982   -1.66413092]] (4, 2)
# The log likelihood at the iteration 19 is: -82.66028527383348
# [[  9.31409235   0.77713476]
#  [ 21.41096135  -5.4806598 ]
#  [-29.70708943   2.75193629]
#  [-13.69563091  -1.811651  ]] (4, 2)
# The log likelihood at the iteration 20 is: -81.84064081734401
# [[  9.06798247   0.90294795]
#  [ 20.94717352  -5.23896383]
#  [-29.13041457   2.45311312]
#  [-13.4227387   -1.95168726]] (4, 2)
# The log likelihood at the iteration 21 is: -81.05494301707742
# [[  8.83354973   1.02381669]
#  [ 20.50062148  -5.00796939]
#  [-28.57105085   2.16938454]
#  [-13.15846263  -2.08459348]] (4, 2)
# The log likelihood at the iteration 22 is: -80.30122835272152
# [[  8.61026496   1.13998541]
#  [ 20.07068035  -4.78714159]
#  [-28.02853613   1.89999344]
#  [-12.90254949  -2.21072681]] (4, 2)
# The log likelihood at the iteration 23 is: -79.57765973588589
# [[  8.39756757   1.25165467]
#  [ 19.65670225  -4.57598189]
#  [-27.50241731   1.64418488]
#  [-12.65474834  -2.33043975]] (4, 2)
# The log likelihood at the iteration 24 is: -78.88251899893487
# [[  8.19489054   1.35899799]
#  [ 19.2580333   -4.37402099]
#  [-26.99224292   1.40122064]
#  [-12.41480912  -2.4440751 ]] (4, 2)
# The log likelihood at the iteration 25 is: -78.21419955554474
# [[  8.00167601   1.46217231]
#  [ 18.87402514  -4.18081452]
#  [-26.49755995   1.17038826]
#  [-12.18248245  -2.55196283]] (4, 2)
# The log likelihood at the iteration 26 is: -77.57119930376116
# [[  7.81738479   1.56132436]
#  [ 18.50404243  -3.99594019]
#  [-26.01791336   0.95100625]
#  [-11.95752011  -2.65441831]] (4, 2)
# The log likelihood at the iteration 27 is: -76.95211382024856
# [[  7.64150174   1.65659438]
#  [ 18.14746787  -3.81899601]
#  [-25.55284695   0.74242678]
#  [-11.73967581  -2.7517414 ]] (4, 2)
# The log likelihood at the iteration 28 is: -76.35562987711586
# [[  7.47353863   1.74811829]
#  [ 17.80370531  -3.64959908]
#  [-25.10190498   0.54403681]
#  [-11.52870602  -2.84421613]] (4, 2)
# The log likelihood at the iteration 29 is: -75.78051929930979
# [[  7.31303518   1.83602878]
#  [ 17.47218151  -3.48738463]
#  [-24.66463401   0.35525803]
#  [-11.32437087  -2.93211087]] (4, 2)
# The log likelihood at the iteration 30 is: -75.22563317031808
# [[  7.15955905   1.92045582]
#  [ 17.15234715  -3.33200536]
#  [-24.24058477   0.17554616]
#  [-11.12643494  -3.01567863]] (4, 2)
# The log likelihood at the iteration 31 is: -74.68989638620603
# [[ 7.01270519e+00  2.00152679e+00]
#  [ 1.68436771e+01 -3.18313072e+00]
#  [-2.38293139e+01  4.38974648e-03]
#  [-1.09346679e+01 -3.09515764e+00]] (4, 2)
# The log likelihood at the iteration 32 is: -74.17230255229126
# [[  6.87209468   2.07936648]
#  [ 16.54567035  -3.04044638]
#  [-23.43038568  -0.15869124]
#  [-10.74884506  -3.17077194]] (4, 2)
# The log likelihood at the iteration 33 is: -73.67190921263278
# [[  6.73737345   2.15409688]
#  [ 16.25784947  -2.90365358]
#  [-23.04337291  -0.31414701]
#  [-10.56874789  -3.24273211]] (4, 2)
# The log likelihood at the iteration 34 is: -73.1878333996257
# [[  6.60821082   2.22583703]
#  [ 15.97976011  -2.77246858]
#  [-22.66785842  -0.46239958]
#  [-10.39416426  -3.31123597]] (4, 2)
# The log likelihood at the iteration 35 is: -72.71924748907853
# [[  6.48429804   2.29470284]
#  [ 15.7109702   -2.646622  ]
#  [-22.30343572  -0.60384446]
#  [-10.22488872  -3.37646926]] (4, 2)
# The log likelihood at the iteration 36 is: -72.26537534498875
# [[  6.36534682   2.36080693]
#  [ 15.45106905  -2.52585831]
#  [-21.94970963  -0.73885224]
#  [-10.06072262  -3.43860644]] (4, 2)
# The log likelihood at the iteration 37 is: -71.82548873764397
# [[  6.25108793   2.42425849]
#  [ 15.19966654  -2.40993514]
#  [-21.60629684  -0.86777021]
#  [ -9.90147422  -3.49781129]] (4, 2)
# The log likelihood at the iteration 38 is: -71.39890401852051
# [[  6.14126987   2.48516318]
#  [ 14.95639213  -2.29862271]
#  [-21.27282612  -0.99092385]
#  [ -9.74695866  -3.55423761]] (4, 2)
# The log likelihood at the iteration 39 is: -70.98497903561959
# [[  6.03565755   2.54362311]
#  [ 14.72089398  -2.19170325]
#  [-20.94893854  -1.10861827]
#  [ -9.59699797  -3.60802986]] (4, 2)
# The log likelihood at the iteration 40 is: -70.58311027328239
# [[  5.9340312    2.59973672]
#  [ 14.49283803  -2.08897041]
#  [-20.63428752  -1.22113957]
#  [ -9.4514209   -3.65932375]] (4, 2)
# The log likelihood at the iteration 41 is: -70.1927302010921
# [[  5.83618514   2.65359886]
#  [ 14.27190706  -1.99022866]
#  [-20.32853878  -1.32875613]
#  [ -9.31006291  -3.7082468 ]] (4, 2)
# The log likelihood at the iteration 42 is: -69.81330481714768
# [[  5.74192686   2.70530078]
#  [ 14.0577999   -1.89529276]
#  [-20.03137022  -1.4317198 ]
#  [ -9.17276595  -3.75491888]] (4, 2)
# The log likelihood at the iteration 43 is: -69.44433137174332
# [[  5.65107598   2.75493016]
#  [ 13.85023051  -1.80398723]
#  [-19.74247177  -1.530267  ]
#  [ -9.03937829  -3.79945271]] (4, 2)
# The log likelihood at the iteration 44 is: -69.08533625827147
# [[  5.56346342   2.80257118]
#  [ 13.64892723  -1.71614582]
#  [-19.46154509  -1.6246198 ]
#  [ -8.90975441  -3.84195435]] (4, 2)
# The log likelihood at the iteration 45 is: -68.73587305896764
# [[  5.47893057   2.84830461]
#  [ 13.45363199  -1.63161098]
#  [-19.18830337  -1.71498689]
#  [ -8.78375474  -3.88252358]] (4, 2)
# The log likelihood at the iteration 46 is: -68.395520733912
# [[  5.39732853   2.89220786]
#  [ 13.26409956  -1.55023346]
#  [-18.92247099  -1.80156448]
#  [ -8.66124547  -3.92125439]] (4, 2)
# The log likelihood at the iteration 47 is: -68.0638819424803
# [[  5.31851742   2.93435511]
#  [ 13.08009688  -1.47187177]
#  [-18.6637832   -1.88453712]
#  [ -8.54209837  -3.95823528]] (4, 2)
# The log likelihood at the iteration 48 is: -67.7405814871922
# [[  5.24236574   2.9748174 ]
#  [ 12.90140236  -1.39639184]
#  [-18.41198577  -1.96407854]
#  [ -8.42619056  -3.9935497 ]] (4, 2)
# The log likelihood at the iteration 49 is: -67.42526487062534
# [[  5.16874979   3.01366269]
#  [ 12.72780529  -1.3236665 ]
#  [-18.16683465  -2.04035232]
#  [ -8.31340434  -4.02727631]] (4, 2)
# The log likelihood at the iteration 50 is: -67.11759695674871
# [[  5.09755311   3.05095605]
#  [ 12.55910521  -1.25357521]
#  [-17.92809564  -2.11351261]
#  [ -8.20362693  -4.05948933]] (4, 2)
# The log likelihood at the iteration 51 is: -66.81726072867671
# [[  5.02866598   3.08675971]
#  [ 12.39511137  -1.18600358]
#  [-17.69554395  -2.18370472]
#  [ -8.0967503   -4.0902588 ]] (4, 2)
# The log likelihood at the iteration 52 is: -66.52395613545214
# [[  4.96198497   3.12113316]
#  [ 12.23564218  -1.12084311]
#  [-17.46896395  -2.25106574]
#  [ -7.99267097  -4.11965089]] (4, 2)
# The log likelihood at the iteration 53 is: -66.23739902103522
# [[  4.89741249   3.15413333]
#  [ 12.08052474  -1.0579908 ]
#  [-17.24814873  -2.31572505]
#  [ -7.89128982  -4.1477281 ]] (4, 2)
# The log likelihood at the iteration 54 is: -65.95732012920405
# [[  4.83485643   3.18581462]
#  [ 11.92959432  -0.99734886]
#  [-17.03289978  -2.37780483]
#  [ -7.7925119   -4.17454953]] (4, 2)
# The log likelihood at the iteration 55 is: -65.68346417856638
# [[  4.77422977   3.21622904]
#  [ 11.78269396  -0.93882443]
#  [-16.82302666  -2.43742055]
#  [ -7.69624623  -4.20017106]] (4, 2)
# The log likelihood at the iteration 56 is: -65.4155890023366
# [[  4.71545024   3.24542631]
#  [ 11.63967402  -0.8823293 ]
#  [-16.61834665  -2.49468135]
#  [ -7.60240564  -4.22464561]] (4, 2)
# The log likelihood at the iteration 57 is: -65.1534647479547
# [[  4.65844003   3.27345398]
#  [ 11.50039179  -0.8277796 ]
#  [-16.41868445  -2.5496905 ]
#  [ -7.51090662  -4.24802324]] (4, 2)
# The log likelihood at the iteration 58 is: -64.89687313201512
# [[  4.60312548   3.30035749]
#  [ 11.36471114  -0.77509564]
#  [-16.22387183  -2.60254572]
#  [ -7.4216691   -4.2703514 ]] (4, 2)
# The log likelihood at the iteration 59 is: -64.64560674633107
# [[  4.54943682   3.32618028]
#  [ 11.23250213  -0.72420161]
#  [-16.03374735  -2.65333959]
#  [ -7.33461635  -4.29167507]] (4, 2)
# The log likelihood at the iteration 60 is: -64.39946841129294
# [[  4.49730795   3.35096391]
#  [ 11.10364071  -0.67502539]
#  [-15.84815607  -2.70215979]
#  [ -7.24967481  -4.31203689]] (4, 2)
# The log likelihood at the iteration 61 is: -64.15827057298384
# [[  4.44667615   3.3747481 ]
#  [ 10.97800841  -0.62749835]
#  [-15.66694927  -2.74908947]
#  [ -7.16677395  -4.33147732]] (4, 2)
# The log likelihood at the iteration 62 is: -63.921834740795624
# [[  4.39748194   3.39757085]
#  [ 10.855492    -0.58155515]
#  [-15.48998415  -2.79420751]
#  [ -7.08584609  -4.35003477]] (4, 2)
# The log likelihood at the iteration 63 is: -63.6899909625481
# [[  4.34966883   3.41946849]
#  [ 10.7359833   -0.53713354]
#  [-15.31712359  -2.83758876]
#  [ -7.00682635  -4.36774572]] (4, 2)
# The log likelihood at the iteration 64 is: -63.462577334349454
# [[  4.30318314   3.44047579]
#  [ 10.61937883  -0.49417423]
#  [-15.14823593  -2.8793043 ]
#  [ -6.92965245  -4.38464484]] (4, 2)
# The log likelihood at the iteration 65 is: -63.23943954265456
# [[  4.25797387   3.46062602]
#  [ 10.50557962  -0.4526207 ]
#  [-14.98319467  -2.91942165]
#  [ -6.85426463  -4.40076507]] (4, 2)
# The log likelihood at the iteration 66 is: -63.020430436178614
# [[  4.21399251   3.47995102]
#  [ 10.39449096  -0.41241907]
#  [-14.82187828  -2.95800502]
#  [ -6.78060553  -4.41613777]] (4, 2)
# The log likelihood at the iteration 67 is: -62.805409625505774
# [[  4.17119288   3.49848126]
#  [ 10.2860222   -0.37351793]
#  [-14.66416999  -2.99511545]
#  [ -6.70862005  -4.43079275]] (4, 2)
# The log likelihood at the iteration 68 is: -62.59424310840151
# [[  4.12953102   3.51624591]
#  [ 10.18008652  -0.33586824]
#  [-14.50995755  -3.03081102]
#  [ -6.6382553   -4.44475842]] (4, 2)
# The log likelihood at the iteration 69 is: -62.38680291899323
# [[  4.08896506   3.53327291]
#  [ 10.07660073  -0.29942317]
#  [-14.35913305  -3.06514703]
#  [ -6.56946045  -4.45806182]] (4, 2)
# The log likelihood at the iteration 70 is: -62.18296679912432
# [[  4.04945508   3.54958903]
#  [  9.97548515  -0.26413802]
#  [-14.21159271  -3.09817617]
#  [ -6.50218669  -4.47072873]] (4, 2)
# The log likelihood at the iteration 71 is: -61.982617890318636
# [[  4.01096302   3.5652199 ]
#  [  9.87666335  -0.22997007]
#  [-14.06723674  -3.1299486 ]
#  [ -6.43638707  -4.48278372]] (4, 2)
# The log likelihood at the iteration 72 is: -61.78564444491136
# [[  3.97345255   3.58019009]
#  [  9.78006207  -0.19687852]
#  [-13.92596911  -3.16051219]
#  [ -6.37201648  -4.49425022]] (4, 2)
# The log likelihood at the iteration 73 is: -61.59193955501322
# [[  3.93688903   3.59452315]
#  [  9.68561099  -0.16482434]
#  [-13.78769743  -3.18991257]
#  [ -6.30903153  -4.50515061]] (4, 2)
# The log likelihood at the iteration 74 is: -61.40140089807518
# [[  3.90123933   3.60824165]
#  [  9.59324264  -0.13377023]
#  [-13.65233277  -3.21819328]
#  [ -6.24739048  -4.51550623]] (4, 2)
# The log likelihood at the iteration 75 is: -61.21393049791528
# [[  3.86647182   3.62136724]
#  [  9.50289227  -0.10368048]
#  [-13.51978952  -3.2453959 ]
#  [ -6.18705319  -4.52533748]] (4, 2)
# The log likelihood at the iteration 76 is: -61.029434500152774
# [[  3.83255626   3.6339207 ]
#  [  9.41449765  -0.07452093]
#  [-13.38998523  -3.27156014]
#  [ -6.12798102  -4.53466383]] (4, 2)
# The log likelihood at the iteration 77 is: -60.84782296107562
# [[  3.79946373   3.64592195]
#  [  9.32799904  -0.04625888]
#  [-13.26284049  -3.29672393]
#  [ -6.07013677  -4.54350391]] (4, 2)
# The log likelihood at the iteration 78 is: -60.669009649037804
# [[  3.76716657   3.65739011]
#  [  9.24333901  -0.018863  ]
#  [-13.13827879  -3.32092354]
#  [ -6.01348462  -4.55187552]] (4, 2)
# The log likelihood at the iteration 79 is: -60.49291185755077
# [[ 3.73563827e+00  3.66834353e+00]
#  [ 9.16046234e+00  7.69672068e-03]
#  [-1.30162264e+01 -3.34419366e+00]
#  [-5.95799008e+00 -4.55979571e+00]] (4, 2)
# The log likelihood at the iteration 80 is: -60.31945022929427
# [[  3.70485347   3.67879985]
#  [  9.07931595   0.03344903]
#  [-12.89661227  -3.36656746]
#  [ -5.90361992  -4.56728077]] (4, 2)
# The log likelihood at the iteration 81 is: -60.14854859032778
# [[  3.67478788   3.68877599]
#  [  8.99984876   0.05842151]
#  [-12.77936786  -3.38807671]
#  [ -5.85034211  -4.57434632]] (4, 2)
# The log likelihood at the iteration 82 is: -59.98013379383703
# [[  3.64541819   3.69828822]
#  [  8.92201163   0.08264059]
#  [-12.66442709  -3.4087518 ]
#  [ -5.79812579  -4.5810073 ]] (4, 2)
# The log likelihood at the iteration 83 is: -59.81413557279617
# [[  3.61672208   3.70735217]
#  [  8.84575726   0.10613164]
#  [-12.55172623  -3.42862188]
#  [ -5.7469412   -4.58727803]] (4, 2)
# The log likelihood at the iteration 84 is: -59.650486400973016
# [[  3.58867813   3.71598286]
#  [  8.77104009   0.12891901]
#  [-12.44120377  -3.44771485]
#  [ -5.69675964  -4.59317225]] (4, 2)
# The log likelihood at the iteration 85 is: -59.48912136174237
# [[  3.56126577   3.72419472]
#  [  8.69781626   0.15102606]
#  [-12.33280035  -3.46605746]
#  [ -5.64755343  -4.59870312]] (4, 2)
# The log likelihood at the iteration 86 is: -59.32997802421306
# [[  3.53446527   3.73200166]
#  [  8.6260435    0.17247524]
#  [-12.22645869  -3.48367537]
#  [ -5.59929585  -4.60388327]] (4, 2)
# The log likelihood at the iteration 87 is: -59.172996326207326
# [[  3.50825768   3.73941703]
#  [  8.55568107   0.19328809]
#  [-12.12212344  -3.50059321]
#  [ -5.55196113  -4.60872481]] (4, 2)
# The log likelihood at the iteration 88 is: -59.0181184636637
# [[  3.48262479   3.74645369]
#  [  8.4866897    0.21348533]
#  [-12.01974118  -3.51683459]
#  [ -5.50552438  -4.61323937]] (4, 2)
# The log likelihood at the iteration 89 is: -58.86528878606489
# [[  3.45754911   3.75312401]
#  [  8.41903152   0.23308688]
#  [-11.91926029  -3.53242218]
#  [ -5.45996156  -4.61743812]] (4, 2)
# The log likelihood at the iteration 90 is: -58.71445369751835
# [[  3.43301382   3.7594399 ]
#  [  8.35267      0.25211186]
#  [-11.82063089  -3.54737778]
#  [ -5.41524948  -4.62133179]] (4, 2)
# The log likelihood at the iteration 91 is: -58.56556156314393
# [[  3.40900272   3.76541284]
#  [  8.28756988   0.2705787 ]
#  [-11.72380478  -3.5617223 ]
#  [ -5.3713657   -4.62493067]] (4, 2)
# The log likelihood at the iteration 92 is: -58.418562620445876
# [[  3.38550027   3.77105386]
#  [  8.22369716   0.28850511]
#  [-11.62873535  -3.57547585]
#  [ -5.32828855  -4.62824469]] (4, 2)
# The log likelihood at the iteration 93 is: -58.27340889536796
# [[  3.36249148   3.77637361]
#  [  8.16101899   0.30590813]
#  [-11.53537755  -3.58865775]
#  [ -5.28599711  -4.63128336]] (4, 2)
# The log likelihood at the iteration 94 is: -58.13005412275119
# [[  3.33996192   3.78138235]
#  [  8.09950365   0.32280416]
#  [-11.44368779  -3.60128661]
#  [ -5.24447112  -4.63405585]] (4, 2)
# The log likelihood at the iteration 95 is: -57.98845367093247
# [[  3.31789772   3.78608996]
#  [  8.03912051   0.33920902]
#  [-11.35362391  -3.6133803 ]
#  [ -5.20369099  -4.63657096]] (4, 2)
# The log likelihood at the iteration 96 is: -57.84856447023865
# [[  3.29628548   3.79050596]
#  [  7.97983996   0.35513791]
#  [-11.26514512  -3.62495603]
#  [ -5.1636378   -4.63883718]] (4, 2)
# The log likelihood at the iteration 97 is: -57.71034494514826
# [[  3.27511233   3.79463955]
#  [  7.9216334    0.3706055 ]
#  [-11.17821193  -3.63603036]
#  [ -5.12429323  -4.64086267]] (4, 2)
# The log likelihood at the iteration 98 is: -57.57375494990631
# [[  3.25436582   3.7984996 ]
#  [  7.86447318   0.38562591]
#  [-11.09278612  -3.64661925]
#  [ -5.08563953  -4.6426553 ]] (4, 2)
# The log likelihood at the iteration 99 is: -57.43875570739339
# [[  3.23403397   3.80209464]
#  [  7.80833254   0.40021278]
#  [-11.00883069  -3.65673805]
#  [ -5.04765956  -4.64422265]] (4, 2)
# The log likelihood at the iteration 100 is: -57.30530975106113
# [[  3.21410523   3.80543294]
#  [  7.75318562   0.41437923]
#  [-10.92630978  -3.66640156]
#  [ -5.01033669  -4.645572  ]] (4, 2)
# The log likelihood at the iteration 101 is: -57.17338086975951
# [[  3.19456844   3.80852246]
#  [  7.6990074    0.42813794]
#  [-10.84518869  -3.67562405]
#  [ -4.97365485  -4.64671039]] (4, 2)
# The log likelihood at the iteration 102 is: -57.0429340552919
# [[  3.17541284   3.81137088]
#  [  7.64577367   0.44150111]
#  [-10.76543376  -3.68441927]
#  [ -4.93759844  -4.64764461]] (4, 2)
# The log likelihood at the iteration 103 is: -56.91393545254496
# [[  3.15662804   3.81398564]
#  [  7.59346099   0.45448055]
#  [-10.6870124   -3.69280048]
#  [ -4.90215238  -4.64838118]] (4, 2)
# The log likelihood at the iteration 104 is: -56.786352312048315
# [[  3.138204     3.8163739 ]
#  [  7.54204665   0.46708763]
#  [-10.60989301  -3.70078046]
#  [ -4.86730203  -4.64892643]] (4, 2)
# The log likelihood at the iteration 105 is: -56.66015294483033
# [[  3.12013102   3.81854259]
#  [  7.4915087    0.47933335]
#  [-10.53404494  -3.70837155]
#  [ -4.83303322  -4.64928642]] (4, 2)
# The log likelihood at the iteration 106 is: -56.53530667944267
# [[  3.10239975   3.82049841]
#  [  7.44182584   0.49122832]
#  [-10.4594385   -3.71558566]
#  [ -4.7993322   -4.64946705]] (4, 2)
# The log likelihood at the iteration 107 is: -56.411783821035066
# [[  3.08500113   3.82224783]
#  [  7.39297744   0.5027828 ]
#  [-10.38604485  -3.72243429]
#  [ -4.76618565  -4.64947396]] (4, 2)
# The log likelihood at the iteration 108 is: -56.289555612368886
# [[  3.06792642   3.82379709]
#  [  7.34494354   0.51400667]
#  [-10.31383605  -3.72892854]
#  [ -4.73358064  -4.64931265]] (4, 2)
# The log likelihood at the iteration 109 is: -56.168594196664465
# [[  3.05116714   3.82515225]
#  [  7.29770475   0.52490953]
#  [-10.24278497  -3.73507911]
#  [ -4.70150465  -4.64898839]] (4, 2)
# The log likelihood at the iteration 110 is: -56.048872582184465
# [[  3.03471512   3.82631916]
#  [  7.2512423    0.53550061]
#  [-10.17286528  -3.74089637]
#  [ -4.66994549  -4.64850629]] (4, 2)
# The log likelihood at the iteration 111 is: -55.930364608459776
# [[  3.01856245   3.82730347]
#  [  7.20553797   0.54578886]
#  [-10.10405143  -3.74639033]
#  [ -4.63889138  -4.64787129]] (4, 2)
# The log likelihood at the iteration 112 is: -55.81304491407165
# [[  3.00270145   3.82811065]
#  [  7.16057411   0.55578294]
#  [-10.0363186   -3.75157066]
#  [ -4.60833086  -4.64708816]] (4, 2)
# The log likelihood at the iteration 113 is: -55.69688890590826
# [[ 2.98712471  3.828746  ]
#  [ 7.11633358  0.56549121]
#  [-9.9696427  -3.75644669]
#  [-4.5782528  -4.6461615 ]] (4, 2)
# The log likelihood at the iteration 114 is: -55.58187272981813
# [[ 2.97182506  3.82921464]
#  [ 7.07279976  0.57492177]
#  [-9.90400033 -3.76102749]
#  [-4.54864641 -4.64509578]] (4, 2)
# The log likelihood at the iteration 115 is: -55.467973242588066
# [[ 2.95679554  3.82952154]
#  [ 7.02995649  0.58408245]
#  [-9.83936876 -3.76532178]
#  [-4.51950119 -4.6438953 ]] (4, 2)
# The log likelihood at the iteration 116 is: -55.35516798517815
# [[ 2.94202942  3.82967149]
#  [ 6.98778813  0.59298083]
#  [-9.77572589 -3.76933802]
#  [-4.49080697 -4.64256424]] (4, 2)
# The log likelihood at the iteration 117 is: -55.24343515714762
# [[ 2.92752017  3.82966916]
#  [ 6.94627947  0.60162425]
#  [-9.71305027 -3.77308441]
#  [-4.46255384 -4.64110664]] (4, 2)
# The log likelihood at the iteration 118 is: -55.13275359221301
# [[ 2.91326146  3.82951903]
#  [ 6.90541573  0.61001981]
#  [-9.65132102 -3.77656887]
#  [-4.43473218 -4.63952639]] (4, 2)
# The log likelihood at the iteration 119 is: -55.023102734879416
# [[ 2.89924718  3.82922549]
#  [ 6.86518257  0.61817441]
#  [-9.59051785 -3.77979905]
#  [-4.40733265 -4.63782728]] (4, 2)
# The log likelihood at the iteration 120 is: -54.9144626180926
# [[ 2.88547138  3.82879275]
#  [ 6.82556605  0.62609471]
#  [-9.53062105 -3.78278239]
#  [-4.38034617 -4.63601296]] (4, 2)
# The log likelihood at the iteration 121 is: -54.80681384185981
# [[ 2.8719283   3.82822491]
#  [ 6.78655263  0.63378715]
#  [-9.47161144 -3.78552608]
#  [-4.35376388 -4.63408699]] (4, 2)
# The log likelihood at the iteration 122 is: -54.700137552791475
# [[ 2.85861235  3.82752595]
#  [ 6.74812915  0.64125802]
#  [-9.41347034 -3.78803707]
#  [-4.32757722 -4.63205279]] (4, 2)
# The log likelihood at the iteration 123 is: -54.59441542451893
# [[ 2.84551811  3.82669971]
#  [ 6.71028282  0.64851336]
#  [-9.35617962 -3.79032212]
#  [-4.30177781 -4.62991369]] (4, 2)
# The log likelihood at the iteration 124 is: -54.48962963894456
# [[ 2.83264032  3.82574992]
#  [ 6.67300119  0.65555907]
#  [-9.29972161 -3.79238776]
#  [-4.27635753 -4.6276729 ]] (4, 2)
# The log likelihood at the iteration 125 is: -54.38576286828396
# [[ 2.81997388  3.82468021]
#  [ 6.63627218  0.66240084]
#  [-9.24407911 -3.79424034]
#  [-4.25130847 -4.62533356]] (4, 2)
# The log likelihood at the iteration 126 is: -54.282798257862325
# [[ 2.80751384  3.82349408]
#  [ 6.60008402  0.6690442 ]
#  [-9.1892354  -3.79588598]
#  [-4.22662294 -4.62289868]] (4, 2)
# The log likelihood at the iteration 127 is: -54.180719409628026
# [[ 2.79525538  3.82219495]
#  [ 6.56442527  0.67549451]
#  [-9.13517419 -3.79733065]
#  [-4.20229344 -4.6203712 ]] (4, 2)
# The log likelihood at the iteration 128 is: -54.07951036634965
# [[ 2.78319382  3.8207861 ]
#  [ 6.52928479  0.68175698]
#  [-9.08187962 -3.79858012]
#  [-4.17831268 -4.61775397]] (4, 2)
# The log likelihood at the iteration 129 is: -53.979155596463436
# [[ 2.77132465  3.81927076]
#  [ 6.49465176  0.68783665]
#  [-9.02933624 -3.79963999]
#  [-4.15467356 -4.61504973]] (4, 2)
# The log likelihood at the iteration 130 is: -53.87963997954151
# [[ 2.75964345  3.81765202]
#  [ 6.46051562  0.69373842]
#  [-8.97752901 -3.80051569]
#  [-4.13136918 -4.61226116]] (4, 2)
# The log likelihood at the iteration 131 is: -53.78094879235047
# [[ 2.74814593  3.8159329 ]
#  [ 6.42686612  0.69946704]
#  [-8.92644327 -3.80121249]
#  [-4.10839279 -4.60939086]] (4, 2)
# The log likelihood at the iteration 132 is: -53.68306769547345
# [[ 2.73682794  3.81411635]
#  [ 6.39369327  0.70502712]
#  [-8.87606474 -3.8017355 ]
#  [-4.08573783 -4.60644135]] (4, 2)
# The log likelihood at the iteration 133 is: -53.58598272046955
# [[ 2.72568544  3.81220519]
#  [ 6.36098733  0.71042315]
#  [-8.82637951 -3.8020897 ]
#  [-4.06339793 -4.60341506]] (4, 2)
# The log likelihood at the iteration 134 is: -53.48968025754604
# [[ 2.71471449  3.8102022 ]
#  [ 6.32873882  0.71565948]
#  [-8.77737402 -3.80227989]
#  [-4.04136685 -4.60031437]] (4, 2)
# The log likelihood at the iteration 135 is: -53.394147043718974
# [[ 2.70391127  3.80811006]
#  [ 6.29693853  0.72074032]
#  [-8.72903506 -3.80231075]
#  [-4.01963852 -4.59714157]] (4, 2)
# The log likelihood at the iteration 136 is: -53.299370151441025
# [[ 2.69327207  3.80593136]
#  [ 6.26557745  0.72566978]
#  [-8.68134972 -3.80218682]
#  [-3.99820703 -4.59389891]] (4, 2)
# The log likelihood at the iteration 137 is: -53.20533697767479
# [[ 2.68279327  3.80366865]
#  [ 6.23464683  0.73045184]
#  [-8.63430544 -3.80191252]
#  [-3.97706662 -4.59058854]] (4, 2)
# The log likelihood at the iteration 138 is: -53.11203523339158
# [[ 2.67247135  3.80132439]
#  [ 6.20413812  0.73509039]
#  [-8.58788998 -3.80149211]
#  [-3.95621166 -4.58721257]] (4, 2)
# The log likelihood at the iteration 139 is: -53.01945293347692
# [[ 2.6623029   3.79890095]
#  [ 6.17404301  0.73958917]
#  [-8.54209138 -3.80092978]
#  [-3.93563668 -4.58377305]] (4, 2)
# The log likelihood at the iteration 140 is: -52.92757838702397
# [[ 2.65228458  3.79640067]
#  [ 6.14435338  0.74395184]
#  [-8.49689797 -3.80022955]
#  [-3.91533632 -4.58027197]] (4, 2)
# The log likelihood at the iteration 141 is: -52.83640018799894
# [[ 2.64241316  3.79382579]
#  [ 6.11506133  0.74818197]
#  [-8.45229839 -3.79939535]
#  [-3.89530537 -4.57671125]] (4, 2)
# The log likelihood at the iteration 142 is: -52.74590720626073
# [[ 2.63268548  3.79117852]
#  [ 6.08615914  0.75228299]
#  [-8.40828153 -3.798431  ]
#  [-3.87553875 -4.57309276]] (4, 2)
# The log likelihood at the iteration 143 is: -52.65608857892017
# [[ 2.62309847  3.78846099]
#  [ 6.05763929  0.75625828]
#  [-8.36483656 -3.79734021]
#  [-3.85603149 -4.56941833]] (4, 2)
# The log likelihood at the iteration 144 is: -52.5669337020242
# [[ 2.61364915  3.78567526]
#  [ 6.02949445  0.7601111 ]
#  [-8.3219529  -3.79612658]
#  [-3.83677875 -4.56568973]] (4, 2)
# The log likelihood at the iteration 145 is: -52.47843222254998
# [[ 2.60433461  3.78282335]
#  [ 6.00171746  0.76384462]
#  [-8.27962024 -3.79479362]
#  [-3.8177758  -4.56190868]] (4, 2)
# The log likelihood at the iteration 146 is: -52.39057403069684
# [[ 2.595152    3.77990722]
#  [ 5.97430133  0.76746193]
#  [-8.23782851 -3.79334473]
#  [-3.79901803 -4.55807685]] (4, 2)
# The log likelihood at the iteration 147 is: -52.3033492524625
# [[ 2.58609857  3.77692878]
#  [ 5.94723926  0.77096603]
#  [-8.19656785 -3.79178323]
#  [-3.78050093 -4.55419586]] (4, 2)
# The log likelihood at the iteration 148 is: -52.216748242491605
# [[ 2.57717163  3.77388989]
#  [ 5.9205246   0.77435986]
#  [-8.15582866 -3.79011234]
#  [-3.7622201  -4.55026729]] (4, 2)
# The log likelihood at the iteration 149 is: -52.130761577185545
# [[ 2.56836855  3.77079234]
#  [ 5.89415085  0.77764625]
#  [-8.11560156 -3.78833519]
#  [-3.74417126 -4.54629269]] (4, 2)
# The log likelihood at the iteration 150 is: -52.04538004806156
# [[ 2.55968679  3.76763789]
#  [ 5.86811168  0.78082796]
#  [-8.07587738 -3.78645483]
#  [-3.72635019 -4.54227354]] (4, 2)
# The log likelihood at the iteration 151 is: -51.96059465535212
# [[ 2.55112385  3.76442824]
#  [ 5.84240091  0.7839077 ]
#  [-8.03664716 -3.78447422]
#  [-3.70875282 -4.5382113 ]] (4, 2)
# The log likelihood at the iteration 152 is: -51.87639660183321
# [[ 2.54267731  3.76116506]
#  [ 5.8170125   0.78688808]
#  [-7.99790215 -3.78239626]
#  [-3.69137513 -4.53410737]] (4, 2)
# The log likelihood at the iteration 153 is: -51.792777286872855
# [[ 2.5343448   3.75784997]
#  [ 5.79194055  0.78977165]
#  [-7.95963381 -3.78022374]
#  [-3.67421322 -4.52996315]] (4, 2)
# The log likelihood at the iteration 154 is: -51.70972830069089
# [[ 2.52612402  3.75448453]
#  [ 5.76717929  0.7925609 ]
#  [-7.92183376 -3.77795941]
#  [-3.65726327 -4.52577995]] (4, 2)
# The log likelihood at the iteration 155 is: -51.627241418820425
# [[ 2.51801271  3.75107027]
#  [ 5.74272311  0.79525824]
#  [-7.88449385 -3.77560591]
#  [-3.64052153 -4.52155909]] (4, 2)
# The log likelihood at the iteration 156 is: -51.54530859676419
# [[ 2.51000869  3.74760869]
#  [ 5.7185665   0.79786603]
#  [-7.84760609 -3.77316583]
#  [-3.62398437 -4.51730182]] (4, 2)
# The log likelihood at the iteration 157 is: -51.463921964836494
# [[ 2.5021098   3.74410124]
#  [ 5.6947041   0.80038656]
#  [-7.81116267 -3.7706417 ]
#  [-3.60764821 -4.51300939]] (4, 2)
# The log likelihood at the iteration 158 is: -51.383073823184425
# [[ 2.49431398  3.74054933]
#  [ 5.67113066  0.80282206]
#  [-7.77515595 -3.76803597]
#  [-3.59150956 -4.50868298]] (4, 2)
# The log likelihood at the iteration 159 is: -51.3027566369802
# [[ 2.48661917  3.73695434]
#  [ 5.64784104  0.8051747 ]
#  [-7.73957848 -3.76535102]
#  [-3.57556503 -4.50432377]] (4, 2)
# The log likelihood at the iteration 160 is: -51.22296303177882
# [[ 2.4790234   3.73331759]
#  [ 5.62483024  0.80744661]
#  [-7.70442294 -3.76258917]
#  [-3.55981126 -4.49993289]] (4, 2)
# The log likelihood at the iteration 161 is: -51.14368578903317
# [[ 2.47152472  3.7296404 ]
#  [ 5.60209336  0.80963984]
#  [-7.6696822  -3.75975269]
#  [-3.54424501 -4.49551145]] (4, 2)
# The log likelihood at the iteration 162 is: -51.064917841762096
# [[ 2.46412125  3.72592404]
#  [ 5.57962559  0.81175641]
#  [-7.63534927 -3.75684379]
#  [-3.52886308 -4.49106051]] (4, 2)
# The log likelihood at the iteration 163 is: -50.98665227036361
# [[ 2.45681113  3.72216974]
#  [ 5.55742227  0.81379827]
#  [-7.60141732 -3.7538646 ]
#  [-3.51366236 -4.48658114]] (4, 2)
# The log likelihood at the iteration 164 is: -50.90888229856901
# [[ 2.44959257  3.71837871]
#  [ 5.53547881  0.81576733]
#  [-7.56787965 -3.75081723]
#  [-3.49863978 -4.48207434]] (4, 2)
# The log likelihood at the iteration 165 is: -50.83160128953161
# [[ 2.4424638   3.71455212]
#  [ 5.51379074  0.81766544]
#  [-7.53472973 -3.7477037 ]
#  [-3.48379237 -4.47754111]] (4, 2)
# The log likelihood at the iteration 166 is: -50.75480274204526
# [[ 2.4354231   3.71069111]
#  [ 5.49235366  0.81949443]
#  [-7.50196113 -3.74452601]
#  [-3.46911721 -4.47298242]] (4, 2)
# The log likelihood at the iteration 167 is: -50.67848028688761
# [[ 2.4284688   3.7067968 ]
#  [ 5.47116329  0.82125605]
#  [-7.46956761 -3.74128607]
#  [-3.45461142 -4.46839921]] (4, 2)
# The log likelihood at the iteration 168 is: -50.60262768328304
# [[ 2.42159926  3.70287026]
#  [ 5.45021545  0.82295203]
#  [-7.43754301 -3.73798578]
#  [-3.44027222 -4.46379239]] (4, 2)
# The log likelihood at the iteration 169 is: -50.527238815481326
# [[ 2.41481287  3.69891257]
#  [ 5.42950603  0.82458405]
#  [-7.40588133 -3.73462697]
#  [-3.42609687 -4.45916286]] (4, 2)
# The log likelihood at the iteration 170 is: -50.45230768944722
# [[ 2.40810808  3.69492474]
#  [ 5.40903102  0.82615373]
#  [-7.37457669 -3.73121143]
#  [-3.41208268 -4.45451149]] (4, 2)
# The log likelihood at the iteration 171 is: -50.377828429656454
# [[ 2.40148336  3.69090778]
#  [ 5.38878648  0.82766268]
#  [-7.34362332 -3.72774089]
#  [-3.39822703 -4.44983912]] (4, 2)
# The log likelihood at the iteration 172 is: -50.30379527599519
# [[ 2.3949372   3.68686268]
#  [ 5.36876858  0.82911245]
#  [-7.31301558 -3.72421706]
#  [-3.38452735 -4.44514658]] (4, 2)
# The log likelihood at the iteration 173 is: -50.23020258075808
# [[ 2.38846817  3.68279037]
#  [ 5.34897356  0.83050454]
#  [-7.28274795 -3.72064158]
#  [-3.37098112 -4.44043467]] (4, 2)
# The log likelihood at the iteration 174 is: -50.157044805741734
# [[ 2.38207482  3.67869179]
#  [ 5.32939772  0.83184045]
#  [-7.25281501 -3.71701608]
#  [-3.35758587 -4.43570417]] (4, 2)
# The log likelihood at the iteration 175 is: -50.08431651943003
# [[ 2.37575577  3.67456785]
#  [ 5.31003747  0.83312162]
#  [-7.22321147 -3.71334212]
#  [-3.34433919 -4.43095585]] (4, 2)
# The log likelihood at the iteration 176 is: -50.01201239426785
# [[ 2.36950966  3.67041943]
#  [ 5.29088927  0.83434944]
#  [-7.19393212 -3.70962124]
#  [-3.33123872 -4.42619045]] (4, 2)
# The log likelihood at the iteration 177 is: -49.940127204019916
# [[ 2.36333516  3.66624738]
#  [ 5.27194967  0.83552528]
#  [-7.16497188 -3.70585492]
#  [-3.31828214 -4.4214087 ]] (4, 2)
# The log likelihood at the iteration 178 is: -49.868655821211995
# [[ 2.35723096  3.66205256]
#  [ 5.25321528  0.8366505 ]
#  [-7.13632576 -3.70204462]
#  [-3.30546717 -4.41661129]] (4, 2)
# The log likelihood at the iteration 179 is: -49.79759321465093
# [[ 2.35119579  3.65783576]
#  [ 5.23468279  0.83772638]
#  [-7.10798887 -3.69819177]
#  [-3.2927916  -4.41179892]] (4, 2)
# The log likelihood at the iteration 180 is: -49.7269344470212
# [[ 2.34522841  3.6535978 ]
#  [ 5.21634895  0.8387542 ]
#  [-7.07995642 -3.69429774]
#  [-3.28025323 -4.40697225]] (4, 2)
# The log likelihood at the iteration 181 is: -49.65667467255485
# [[ 2.33932761  3.64933944]
#  [ 5.19821057  0.83973521]
#  [-7.05222372 -3.69036388]
#  [-3.26784995 -4.40213194]] (4, 2)
# The log likelihood at the iteration 182 is: -49.58680913477263
# [[ 2.3334922   3.64506145]
#  [ 5.18026455  0.84067061]
#  [-7.02478616 -3.68639151]
#  [-3.25557965 -4.39727862]] (4, 2)
# The log likelihood at the iteration 183 is: -49.51733316429313
# [[ 2.327721    3.64076456]
#  [ 5.16250783  0.84156158]
#  [-6.99763923 -3.68238191]
#  [-3.24344028 -4.39241292]] (4, 2)
# The log likelihood at the iteration 184 is: -49.44824217670836
# [[ 2.32201289  3.63644949]
#  [ 5.14493742  0.84240928]
#  [-6.97077851 -3.67833633]
#  [-3.23142983 -4.38753542]] (4, 2)
# The log likelihood at the iteration 185 is: -49.37953167052279
# [[ 2.31636675  3.63211695]
#  [ 5.12755038  0.84321483]
#  [-6.94419965 -3.67425598]
#  [-3.21954633 -4.38264674]] (4, 2)
# The log likelihood at the iteration 186 is: -49.31119722515364
# [[ 2.3107815   3.62776762]
#  [ 5.11034385  0.84397933]
#  [-6.91789841 -3.67014207]
#  [-3.20778784 -4.37774742]] (4, 2)
# The log likelihood at the iteration 187 is: -49.24323449899112
# [[ 2.30525607  3.62340217]
#  [ 5.09331501  0.84470384]
#  [-6.89187061 -3.66599574]
#  [-3.19615247 -4.37283804]] (4, 2)
# The log likelihood at the iteration 188 is: -49.175639227515106
# [[ 2.29978941  3.61902124]
#  [ 5.07646109  0.84538942]
#  [-6.86611216 -3.66181813]
#  [-3.18463835 -4.36791915]] (4, 2)
# The log likelihood at the iteration 189 is: -49.10840722146782
# [[ 2.29438051  3.61462548]
#  [ 5.0597794   0.84603708]
#  [-6.84061904 -3.65761033]
#  [-3.17324367 -4.36299126]] (4, 2)
# The log likelihood at the iteration 190 is: -49.04153436507944
# [[ 2.28902837  3.6102155 ]
#  [ 5.04326728  0.84664782]
#  [-6.81538732 -3.65337344]
#  [-3.16196663 -4.35805489]] (4, 2)
# The log likelihood at the iteration 191 is: -48.97501661434563
# [[ 2.28373201  3.6057919 ]
#  [ 5.02692213  0.84722261]
#  [-6.79041313 -3.64910848]
#  [-3.15080548 -4.35311056]] (4, 2)
# The log likelihood at the iteration 192 is: -48.90884999535438
# [[ 2.27849047  3.60135528]
#  [ 5.0107414   0.84776239]
#  [-6.76569269 -3.64481649]
#  [-3.1397585  -4.34815875]] (4, 2)
# The log likelihood at the iteration 193 is: -48.84303060266151
# [[ 2.27330283  3.59690621]
#  [ 4.99472259  0.8482681 ]
#  [-6.74122228 -3.64049846]
#  [-3.12882401 -4.34319993]] (4, 2)
# The log likelihood at the iteration 194 is: -48.777554597712516
# [[ 2.26816816  3.59244525]
#  [ 4.97886325  0.84874063]
#  [-6.71699823 -3.63615537]
#  [-3.11800033 -4.33823459]] (4, 2)
# The log likelihood at the iteration 195 is: -48.71241820730915
# [[ 2.26308558  3.58797294]
#  [ 4.96316098  0.84918086]
#  [-6.69301699 -3.63178817]
#  [-3.10728586 -4.33326316]] (4, 2)
# The log likelihood at the iteration 196 is: -48.64761772211958
# [[ 2.25805419  3.58348982]
#  [ 4.94761341  0.84958967]
#  [-6.66927502 -3.62739778]
#  [-3.09667898 -4.3282861 ]] (4, 2)
# The log likelihood at the iteration 197 is: -48.583149495230806
# [[ 2.25307314  3.57899641]
#  [ 4.93221824  0.84996788]
#  [-6.64576887 -3.62298509]
#  [-3.08617815 -4.32330383]] (4, 2)
# The log likelihood at the iteration 198 is: -48.51900994074126
# [[ 2.24814159  3.57449322]
#  [ 4.91697318  0.85031632]
#  [-6.62249517 -3.61855101]
#  [-3.07578181 -4.31831678]] (4, 2)
# The log likelihood at the iteration 199 is: -48.45519553239287
# [[ 2.24325872  3.56998073]
#  [ 4.90187603  0.85063579]
#  [-6.59945059 -3.61409638]
#  [-3.06548847 -4.31332535]] (4, 2)
# The log likelihood at the iteration 200 is: -48.391702802241404
# [[ 2.23842371  3.56545943]
#  [ 4.88692459  0.85092706]
#  [-6.57663185 -3.60962203]
#  [-3.05529663 -4.30832995]] (4, 2)
# The log likelihood at the iteration 201 is: -48.32852833936292
# [[ 2.23363578  3.5609298 ]
#  [ 4.87211671  0.85119091]
#  [-6.55403577 -3.6051288 ]
#  [-3.04520486 -4.30333097]] (4, 2)
# The log likelihood at the iteration 202 is: -48.26566878859646
# [[ 2.22889415  3.55639228]
#  [ 4.8574503   0.85142808]
#  [-6.53165918 -3.60061747]
#  [-3.03521171 -4.29832878]] (4, 2)
# The log likelihood at the iteration 203 is: -48.203120849320804
# [[ 2.22419806  3.55184734]
#  [ 4.84292329  0.85163929]
#  [-6.509499   -3.59608883]
#  [-3.0253158  -4.29332375]] (4, 2)
# The log likelihood at the iteration 204 is: -48.14088127426444
# [[ 2.21954677  3.54729539]
#  [ 4.82853365  0.85182525]
#  [-6.48755219 -3.59154362]
#  [-3.01551574 -4.28831625]] (4, 2)
# The log likelihood at the iteration 205 is: -48.07894686834803
# [[ 2.21493955  3.54273688]
#  [ 4.8142794   0.85198667]
#  [-6.46581578 -3.5869826 ]
#  [-3.00581018 -4.28330663]] (4, 2)
# The log likelihood at the iteration 206 is: -48.01731448755791
# [[ 2.21037569  3.53817221]
#  [ 4.80015859  0.85212421]
#  [-6.44428683 -3.58240648]
#  [-2.9961978  -4.27829522]] (4, 2)
# The log likelihood at the iteration 207 is: -47.95598103784997
# [[ 2.20585449  3.53360179]
#  [ 4.78616929  0.85223853]
#  [-6.42296247 -3.57781597]
#  [-2.98667729 -4.27328237]] (4, 2)
# The log likelihood at the iteration 208 is: -47.89494347408257
# [[ 2.20137527  3.52902602]
#  [ 4.77230962  0.85233029]
#  [-6.40183986 -3.57321176]
#  [-2.97724738 -4.26826839]] (4, 2)
# The log likelihood at the iteration 209 is: -47.834198798977916
# [[ 2.19693734  3.52444527]
#  [ 4.75857775  0.85240011]
#  [-6.38091625 -3.5685945 ]
#  [-2.9679068  -4.26325361]] (4, 2)
# The log likelihood at the iteration 210 is: -47.773744062111156
# [[ 2.19254006  3.51985994]
#  [ 4.74497185  0.85244862]
#  [-6.36018889 -3.56396487]
#  [-2.95865432 -4.25823833]] (4, 2)
# The log likelihood at the iteration 211 is: -47.713576358925465
# [[ 2.18818277  3.51527037]
#  [ 4.73149015  0.8524764 ]
#  [-6.33965511 -3.55932349]
#  [-2.94948873 -4.25322286]] (4, 2)
# The log likelihood at the iteration 212 is: -47.65369282977342
# [[ 2.18386485  3.51067694]
#  [ 4.71813089  0.85248404]
#  [-6.31931228 -3.55467099]
#  [-2.94040883 -4.24820748]] (4, 2)
# The log likelihood at the iteration 213 is: -47.594090658983326
# [[ 2.17958568  3.50607998]
#  [ 4.70489237  0.85247213]
#  [-6.2991578  -3.55000797]
#  [-2.93141346 -4.24319248]] (4, 2)
# The log likelihood at the iteration 214 is: -47.53476707394946
# [[ 2.17534465  3.50147984]
#  [ 4.69177288  0.85244122]
#  [-6.27918913 -3.54533502]
#  [-2.92250146 -4.23817814]] (4, 2)
# The log likelihood at the iteration 215 is: -47.47571934424595
# [[ 2.17114116  3.49687685]
#  [ 4.67877078  0.85239185]
#  [-6.25940378 -3.54065273]
#  [-2.9136717  -4.23316473]] (4, 2)
# The log likelihood at the iteration 216 is: -47.41694478076354
# [[ 2.16697463  3.49227134]
#  [ 4.66588444  0.85232457]
#  [-6.23979929 -3.53596165]
#  [-2.90492306 -4.22815252]] (4, 2)
# The log likelihood at the iteration 217 is: -47.3584407348681
# [[ 2.16284448  3.48766361]
#  [ 4.65311226  0.85223988]
#  [-6.22037324 -3.53126233]
#  [-2.89625447 -4.22314176]] (4, 2)
# The log likelihood at the iteration 218 is: -47.300204597580894
# [[ 2.15875016  3.48305398]
#  [ 4.64045267  0.85213831]
#  [-6.20112325 -3.52655531]
#  [-2.88766484 -4.2181327 ]] (4, 2)
# The log likelihood at the iteration 219 is: -47.2422337987793
# [[ 2.15469112  3.47844275]
#  [ 4.62790413  0.85202035]
#  [-6.182047   -3.52184111]
#  [-2.87915311 -4.21312558]] (4, 2)
# The log likelihood at the iteration 220 is: -47.184525806417774
# [[ 2.15066681  3.47383021]
#  [ 4.61546511  0.85188647]
#  [-6.16314218 -3.51712024]
#  [-2.87071826 -4.20812065]] (4, 2)
# The log likelihood at the iteration 221 is: -47.12707812576848
# [[ 2.1466767   3.46921664]
#  [ 4.60313413  0.85173717]
#  [-6.14440654 -3.5123932 ]
#  [-2.86235925 -4.20311813]] (4, 2)
# The log likelihood at the iteration 222 is: -47.06988829868047
# [[ 2.14272028  3.46460232]
#  [ 4.59090973  0.8515729 ]
#  [-6.12583787 -3.50766046]
#  [-2.85407509 -4.19811825]] (4, 2)
# The log likelihood at the iteration 223 is: -47.01295390285788
# [[ 2.13879703  3.45998753]
#  [ 4.57879047  0.85139411]
#  [-6.10743398 -3.50292251]
#  [-2.84586479 -4.19312123]] (4, 2)
# The log likelihood at the iteration 224 is: -46.95627255115538
# [[ 2.13490646  3.45537253]
#  [ 4.56677494  0.85120125]
#  [-6.08919272 -3.49817979]
#  [-2.83772738 -4.18812728]] (4, 2)
# The log likelihood at the iteration 225 is: -46.89984189089112
# [[ 2.13104807  3.45075757]
#  [ 4.55486173  0.85099474]
#  [-6.07111199 -3.49343277]
#  [-2.8296619  -4.18313661]] (4, 2)
# The log likelihood at the iteration 226 is: -46.843659603176725
# [[ 2.12722139  3.44614291]
#  [ 4.5430495   0.85077501]
#  [-6.0531897  -3.48868188]
#  [-2.82166743 -4.17814942]] (4, 2)
# The log likelihood at the iteration 227 is: -46.787723402263374
# [[ 2.12342594  3.44152879]
#  [ 4.53133689  0.85054247]
#  [-6.03542382 -3.48392754]
#  [-2.81374303 -4.17316591]] (4, 2)
# The log likelihood at the iteration 228 is: -46.73203103490385
# [[ 2.11966126  3.43691546]
#  [ 4.51972258  0.85029752]
#  [-6.01781234 -3.47917017]
#  [-2.80588779 -4.16818627]] (4, 2)
# The log likelihood at the iteration 229 is: -46.676580279729826
# [[ 2.11592689  3.43230314]
#  [ 4.50820529  0.85004055]
#  [-6.00035328 -3.47441018]
#  [-2.79810084 -4.16321069]] (4, 2)
# The log likelihood at the iteration 230 is: -46.62136894664439
# [[ 2.1122224   3.42769205]
#  [ 4.49678373  0.84977194]
#  [-5.9830447  -3.46964795]
#  [-2.79038128 -4.15823934]] (4, 2)
# The log likelihood at the iteration 231 is: -46.56639487622882
# [[ 2.10854733  3.42308244]
#  [ 4.48545664  0.84949208]
#  [-5.96588469 -3.46488389]
#  [-2.78272826 -4.15327241]] (4, 2)
# The log likelihood at the iteration 232 is: -46.51165593916362
# [[ 2.10490126  3.4184745 ]
#  [ 4.47422281  0.84920132]
#  [-5.94887136 -3.46011836]
#  [-2.77514093 -4.14831006]] (4, 2)
# The log likelihood at the iteration 233 is: -46.45715003566337
# [[ 2.10128378  3.41386844]
#  [ 4.463081    0.84890003]
#  [-5.93200287 -3.45535172]
#  [-2.76761844 -4.14335247]] (4, 2)
# The log likelihood at the iteration 234 is: -46.40287509492454
# [[ 2.09769446  3.40926448]
#  [ 4.45203003  0.84858854]
#  [-5.91527739 -3.45058434]
#  [-2.76015999 -4.13839979]] (4, 2)
# The log likelihood at the iteration 235 is: -46.34882907458669
# [[ 2.0941329   3.40466282]
#  [ 4.44106873  0.8482672 ]
#  [-5.89869313 -3.44581657]
#  [-2.75276475 -4.13345219]] (4, 2)
# The log likelihood at the iteration 236 is: -46.29500996020603
# [[ 2.0905987   3.40006364]
#  [ 4.43019595  0.84793635]
#  [-5.88224832 -3.44104873]
#  [-2.74543194 -4.12850981]] (4, 2)
# The log likelihood at the iteration 237 is: -46.241415764741255
# [[ 2.08709147  3.39546713]
#  [ 4.41941054  0.8475963 ]
#  [-5.86594123 -3.43628117]
#  [-2.73816076 -4.12357282]] (4, 2)
# The log likelihood at the iteration 238 is: -46.18804452805129
# [[ 2.08361083  3.39087349]
#  [ 4.4087114   0.84724738]
#  [-5.84977015 -3.4315142 ]
#  [-2.73095046 -4.11864134]] (4, 2)
# The log likelihood at the iteration 239 is: -46.13489431640461
# [[ 2.08015639  3.38628289]
#  [ 4.39809742  0.84688988]
#  [-5.8337334  -3.42674814]
#  [-2.72380027 -4.11371553]] (4, 2)
# The log likelihood at the iteration 240 is: -46.081963221999786
# [[ 2.0767278   3.38169551]
#  [ 4.38756753  0.84652413]
#  [-5.81782933 -3.42198328]
#  [-2.71670944 -4.10879551]] (4, 2)
# The log likelihood at the iteration 241 is: -46.02924936249707
# [[ 2.07332468  3.37711151]
#  [ 4.37712066  0.84615039]
#  [-5.80205629 -3.41721994]
#  [-2.70967724 -4.10388144]] (4, 2)
# The log likelihood at the iteration 242 is: -45.9767508805605
# [[ 2.06994667  3.37253106]
#  [ 4.36675576  0.84576898]
#  [-5.78641269 -3.4124584 ]
#  [-2.70270294 -4.09897342]] (4, 2)
# The log likelihood at the iteration 243 is: -45.92446594341045
# [[ 2.06659344  3.36795433]
#  [ 4.35647182  0.84538016]
#  [-5.77089695 -3.40769894]
#  [-2.69578584 -4.0940716 ]] (4, 2)
# The log likelihood at the iteration 244 is: -45.87239274238633
# [[ 2.06326462  3.36338147]
#  [ 4.34626782  0.84498422]
#  [-5.75550751 -3.40294184]
#  [-2.68892523 -4.08917608]] (4, 2)
# The log likelihood at the iteration 245 is: -45.820529492518766
# [[ 2.05995989  3.35881263]
#  [ 4.33614275  0.84458141]
#  [-5.74024284 -3.39818736]
#  [-2.68212042 -4.084287  ]] (4, 2)
# The log likelihood at the iteration 246 is: -45.76887443211174
# [[ 2.05667891  3.35424798]
#  [ 4.32609565  0.84417201]
#  [-5.72510143 -3.39343576]
#  [-2.67537073 -4.07940447]] (4, 2)
# The log likelihood at the iteration 247 is: -45.717425822333844
# [[ 2.05342136  3.34968764]
#  [ 4.31612555  0.84375626]
#  [-5.7100818  -3.3886873 ]
#  [-2.6686755  -4.07452859]] (4, 2)
# The log likelihood at the iteration 248 is: -45.66618194681842
# [[ 2.05018691  3.34513176]
#  [ 4.3062315   0.84333441]
#  [-5.69518249 -3.38394223]
#  [-2.66203406 -4.06965948]] (4, 2)
# The log likelihood at the iteration 249 is: -45.61514111127283
# [[ 2.04697526  3.34058048]
#  [ 4.29641256  0.84290671]
#  [-5.68040205 -3.37920078]
#  [-2.65544577 -4.06479724]] (4, 2)
# The log likelihood at the iteration 250 is: -45.56430164309593
# [[ 2.04378608  3.33603393]
#  [ 4.28666782  0.8424734 ]
#  [-5.66573906 -3.37446319]
#  [-2.64890998 -4.05994197]] (4, 2)
# The log likelihood at the iteration 251 is: -45.513661891004176
# [[ 2.04061908  3.33149225]
#  [ 4.27699637  0.8420347 ]
#  [-5.65119214 -3.36972969]
#  [-2.64242607 -4.05509378]] (4, 2)
# The log likelihood at the iteration 252 is: -45.4632202246658
# [[ 2.03747396  3.32695556]
#  [ 4.26739733  0.84159084]
#  [-5.6367599  -3.36500049]
#  [-2.63599342 -4.05025275]] (4, 2)
# The log likelihood at the iteration 253 is: -45.41297503434267
# [[ 2.03435043  3.32242399]
#  [ 4.2578698   0.84114205]
#  [-5.62244099 -3.36027582]
#  [-2.62961142 -4.04541899]] (4, 2)
# The log likelihood at the iteration 254 is: -45.36292473054023
# [[ 2.03124819  3.31789764]
#  [ 4.24841294  0.84068853]
#  [-5.60823407 -3.35555588]
#  [-2.62327946 -4.04059259]] (4, 2)
# The log likelihood at the iteration 255 is: -45.313067743664625
# [[ 2.02816697  3.31337665]
#  [ 4.23902589  0.8402305 ]
#  [-5.59413783 -3.35084088]
#  [-2.61699696 -4.03577362]] (4, 2)
# The log likelihood at the iteration 256 is: -45.26340252368736
# [[ 2.02510648  3.30886112]
#  [ 4.22970781  0.83976817]
#  [-5.58015097 -3.34613101]
#  [-2.61076334 -4.03096218]] (4, 2)
# The log likelihood at the iteration 257 is: -45.213927539816964
# [[ 2.02206645  3.30435117]
#  [ 4.22045789  0.83930172]
#  [-5.56627221 -3.34142648]
#  [-2.60457801 -4.02615835]] (4, 2)
# The log likelihood at the iteration 258 is: -45.164641280177655
# [[ 2.01904662  3.2998469 ]
#  [ 4.2112753   0.83883137]
#  [-5.55250031 -3.33672745]
#  [-2.59844041 -4.02136221]] (4, 2)
# The log likelihood at the iteration 259 is: -45.115542251494695
# [[ 2.01604672  3.29534841]
#  [ 4.20215926  0.83835729]
#  [-5.53883401 -3.33203413]
#  [-2.59234998 -4.01657383]] (4, 2)
# The log likelihood at the iteration 260 is: -45.0666289787865
# [[ 2.01306648  3.29085581]
#  [ 4.19310897  0.83787967]
#  [-5.5252721  -3.32734668]
#  [-2.58630618 -4.01179329]] (4, 2)
# The log likelihood at the iteration 261 is: -45.017900005063055
# [[ 2.01010566  3.2863692 ]
#  [ 4.18412366  0.8373987 ]
#  [-5.51181338 -3.32266528]
#  [-2.58030846 -4.00702066]] (4, 2)
# The log likelihood at the iteration 262 is: -44.96935389103065
# [[ 2.00716401  3.28188866]
#  [ 4.17520257  0.83691455]
#  [-5.49845665 -3.31799009]
#  [-2.5743563  -4.00225601]] (4, 2)
# ...
# [[ 0.21495481  0.18635437]
#  [ 0.33813154  0.21144192]
#  [-0.45577546 -0.18667267]
#  [-0.25491954 -0.4944739 ]] (4, 2)
# The log likelihood at the iteration 9913 is: -9.457873212102413
# [[ 0.21493573  0.18633795]
#  [ 0.338101    0.21142124]
#  [-0.45573439 -0.18665065]
#  [-0.2548987  -0.49444282]] (4, 2)
# The log likelihood at the iteration 9914 is: -9.45747727354771
# [[ 0.21491665  0.18632153]
#  [ 0.33807046  0.21140057]
#  [-0.45569333 -0.18662864]
#  [-0.25487787 -0.49441175]] (4, 2)
# The log likelihood at the iteration 9915 is: -9.4570814003366
# [[ 0.21489758  0.18630512]
#  [ 0.33803993  0.2113799 ]
#  [-0.45565228 -0.18660664]
#  [-0.25485705 -0.49438068]] (4, 2)
# The log likelihood at the iteration 9916 is: -9.456685592451496
# [[ 0.21487851  0.18628871]
#  [ 0.33800941  0.21135923]
#  [-0.45561124 -0.18658463]
#  [-0.25483622 -0.49434961]] (4, 2)
# The log likelihood at the iteration 9917 is: -9.456289849874814
# [[ 0.21485944  0.1862723 ]
#  [ 0.33797889  0.21133857]
#  [-0.4555702  -0.18656264]
#  [-0.2548154  -0.49431855]] (4, 2)
# The log likelihood at the iteration 9918 is: -9.455894172588986
# [[ 0.21484038  0.18625589]
#  [ 0.33794837  0.21131791]
#  [-0.45552917 -0.18654064]
#  [-0.25479459 -0.4942875 ]] (4, 2)
# The log likelihood at the iteration 9919 is: -9.45549856057644
# [[ 0.21482132  0.18623949]
#  [ 0.33791787  0.21129725]
#  [-0.45548815 -0.18651865]
#  [-0.25477378 -0.49425645]] (4, 2)
# The log likelihood at the iteration 9920 is: -9.455103013819611
# [[ 0.21480226  0.18622309]
#  [ 0.33788736  0.2112766 ]
#  [-0.45544713 -0.18649667]
#  [-0.25475297 -0.49422541]] (4, 2)
# The log likelihood at the iteration 9921 is: -9.454707532300922
# [[ 0.21478321  0.1862067 ]
#  [ 0.33785687  0.21125595]
#  [-0.45540613 -0.18647469]
#  [-0.25473216 -0.49419437]] (4, 2)
# The log likelihood at the iteration 9922 is: -9.454312116002852
# [[ 0.21476416  0.18619031]
#  [ 0.33782638  0.21123531]
#  [-0.45536513 -0.18645271]
#  [-0.25471136 -0.49416333]] (4, 2)
# The log likelihood at the iteration 9923 is: -9.453916764907841
# [[ 0.21474512  0.18617392]
#  [ 0.33779589  0.21121467]
#  [-0.45532414 -0.18643074]
#  [-0.25469057 -0.49413231]] (4, 2)
# The log likelihood at the iteration 9924 is: -9.453521478998349
# [[ 0.21472608  0.18615753]
#  [ 0.33776541  0.21119403]
#  [-0.45528316 -0.18640878]
#  [-0.25466977 -0.49410128]] (4, 2)
# The log likelihood at the iteration 9925 is: -9.453126258256843
# [[ 0.21470704  0.18614115]
#  [ 0.33773494  0.2111734 ]
#  [-0.45524218 -0.18638682]
#  [-0.25464898 -0.49407026]] (4, 2)
# The log likelihood at the iteration 9926 is: -9.452731102665812
# [[ 0.214688    0.18612477]
#  [ 0.33770447  0.21115277]
#  [-0.45520121 -0.18636486]
#  [-0.2546282  -0.49403925]] (4, 2)
# The log likelihood at the iteration 9927 is: -9.452336012207725
# [[ 0.21466897  0.1861084 ]
#  [ 0.33767401  0.21113214]
#  [-0.45516025 -0.18634291]
#  [-0.25460742 -0.49400824]] (4, 2)
# The log likelihood at the iteration 9928 is: -9.451940986865072
# [[ 0.21464994  0.18609202]
#  [ 0.33764356  0.21111152]
#  [-0.4551193  -0.18632096]
#  [-0.25458664 -0.49397724]] (4, 2)
# The log likelihood at the iteration 9929 is: -9.451546026620345
# [[ 0.21463092  0.18607565]
#  [ 0.33761311  0.21109091]
#  [-0.45507836 -0.18629902]
#  [-0.25456586 -0.49394624]] (4, 2)
# The log likelihood at the iteration 9930 is: -9.451151131456045
# [[ 0.2146119   0.18605929]
#  [ 0.33758266  0.21107029]
#  [-0.45503742 -0.18627708]
#  [-0.25454509 -0.49391525]] (4, 2)
# The log likelihood at the iteration 9931 is: -9.450756301354678
# [[ 0.21459288  0.18604292]
#  [ 0.33755223  0.21104968]
#  [-0.45499649 -0.18625514]
#  [-0.25452433 -0.49388426]] (4, 2)
# The log likelihood at the iteration 9932 is: -9.450361536298763
# [[ 0.21457387  0.18602657]
#  [ 0.33752179  0.21102908]
#  [-0.45495557 -0.18623321]
#  [-0.25450357 -0.49385328]] (4, 2)
# The log likelihood at the iteration 9933 is: -9.449966836270812
# [[ 0.21455486  0.18601021]
#  [ 0.33749137  0.21100848]
#  [-0.45491466 -0.18621129]
#  [-0.25448281 -0.4938223 ]] (4, 2)
# The log likelihood at the iteration 9934 is: -9.44957220125336
# [[ 0.21453585  0.18599385]
#  [ 0.33746095  0.21098788]
#  [-0.45487375 -0.18618937]
#  [-0.25446205 -0.49379132]] (4, 2)
# The log likelihood at the iteration 9935 is: -9.449177631228931
# [[ 0.21451685  0.1859775 ]
#  [ 0.33743053  0.21096728]
#  [-0.45483285 -0.18616745]
#  [-0.2544413  -0.49376036]] (4, 2)
# The log likelihood at the iteration 9936 is: -9.448783126180068
# [[ 0.21449785  0.18596116]
#  [ 0.33740012  0.21094669]
#  [-0.45479196 -0.18614554]
#  [-0.25442055 -0.49372939]] (4, 2)
# The log likelihood at the iteration 9937 is: -9.448388686089316
# [[ 0.21447885  0.18594481]
#  [ 0.33736972  0.21092611]
#  [-0.45475108 -0.18612364]
#  [-0.25439981 -0.49369844]] (4, 2)
# The log likelihood at the iteration 9938 is: -9.447994310939228
# [[ 0.21445986  0.18592847]
#  [ 0.33733932  0.21090553]
#  [-0.45471021 -0.18610173]
#  [-0.25437907 -0.49366748]] (4, 2)
# The log likelihood at the iteration 9939 is: -9.447600000712363
# [[ 0.21444087  0.18591214]
#  [ 0.33730893  0.21088495]
#  [-0.45466934 -0.18607984]
#  [-0.25435833 -0.49363654]] (4, 2)
# The log likelihood at the iteration 9940 is: -9.44720575539128
# [[ 0.21442189  0.1858958 ]
#  [ 0.33727855  0.21086437]
#  [-0.45462848 -0.18605794]
#  [-0.2543376  -0.49360559]] (4, 2)
# The log likelihood at the iteration 9941 is: -9.446811574958552
# [[ 0.2144029   0.18587947]
#  [ 0.33724817  0.2108438 ]
#  [-0.45458763 -0.18603605]
#  [-0.25431687 -0.49357466]] (4, 2)
# The log likelihood at the iteration 9942 is: -9.446417459396764
# [[ 0.21438393  0.18586314]
#  [ 0.33721779  0.21082324]
#  [-0.45454678 -0.18601417]
#  [-0.25429615 -0.49354372]] (4, 2)
# The log likelihood at the iteration 9943 is: -9.446023408688491
# [[ 0.21436495  0.18584682]
#  [ 0.33718742  0.21080267]
#  [-0.45450595 -0.18599229]
#  [-0.25427543 -0.4935128 ]] (4, 2)
# The log likelihood at the iteration 9944 is: -9.44562942281632
# [[ 0.21434598  0.1858305 ]
#  [ 0.33715706  0.21078211]
#  [-0.45446512 -0.18597042]
#  [-0.25425471 -0.49348187]] (4, 2)
# The log likelihood at the iteration 9945 is: -9.445235501762856
# [[ 0.21432701  0.18581418]
#  [ 0.3371267   0.21076156]
#  [-0.4544243  -0.18594855]
#  [-0.254234   -0.49345095]] (4, 2)
# The log likelihood at the iteration 9946 is: -9.444841645510706
# [[ 0.21430805  0.18579786]
#  [ 0.33709635  0.21074101]
#  [-0.45438349 -0.18592668]
#  [-0.25421329 -0.49342004]] (4, 2)
# The log likelihood at the iteration 9947 is: -9.444447854042462
# [[ 0.21428909  0.18578155]
#  [ 0.33706601  0.21072046]
#  [-0.45434268 -0.18590482]
#  [-0.25419258 -0.49338913]] (4, 2)
# The log likelihood at the iteration 9948 is: -9.444054127340761
# [[ 0.21427013  0.18576524]
#  [ 0.33703567  0.21069992]
#  [-0.45430188 -0.18588296]
#  [-0.25417188 -0.49335823]] (4, 2)
# The log likelihood at the iteration 9949 is: -9.443660465388213
# [[ 0.21425118  0.18574894]
#  [ 0.33700533  0.21067938]
#  [-0.45426109 -0.18586111]
#  [-0.25415118 -0.49332734]] (4, 2)
# The log likelihood at the iteration 9950 is: -9.443266868167436
# [[ 0.21423223  0.18573263]
#  [ 0.33697501  0.21065884]
#  [-0.45422031 -0.18583926]
#  [-0.25413049 -0.49329644]] (4, 2)
# The log likelihood at the iteration 9951 is: -9.442873335661087
# [[ 0.21421328  0.18571634]
#  [ 0.33694468  0.21063831]
#  [-0.45417953 -0.18581742]
#  [-0.2541098  -0.49326556]] (4, 2)
# The log likelihood at the iteration 9952 is: -9.442479867851793
# [[ 0.21419434  0.18570004]
#  [ 0.33691437  0.21061778]
#  [-0.45413877 -0.18579558]
#  [-0.25408911 -0.49323467]] (4, 2)
# The log likelihood at the iteration 9953 is: -9.442086464722207
# [[ 0.2141754   0.18568375]
#  [ 0.33688406  0.21059725]
#  [-0.45409801 -0.18577375]
#  [-0.25406843 -0.4932038 ]] (4, 2)
# The log likelihood at the iteration 9954 is: -9.441693126254986
# [[ 0.21415646  0.18566746]
#  [ 0.33685375  0.21057673]
#  [-0.45405726 -0.18575192]
#  [-0.25404775 -0.49317292]] (4, 2)
# The log likelihood at the iteration 9955 is: -9.44129985243277
# [[ 0.21413753  0.18565117]
#  [ 0.33682345  0.21055622]
#  [-0.45401651 -0.18573009]
#  [-0.25402707 -0.49314206]] (4, 2)
# The log likelihood at the iteration 9956 is: -9.440906643238254
# [[ 0.2141186   0.18563489]
#  [ 0.33679316  0.2105357 ]
#  [-0.45397577 -0.18570827]
#  [-0.2540064  -0.49311119]] (4, 2)
# The log likelihood at the iteration 9957 is: -9.440513498654106
# [[ 0.21409967  0.18561861]
#  [ 0.33676287  0.21051519]
#  [-0.45393505 -0.18568646]
#  [-0.25398573 -0.49308034]] (4, 2)
# The log likelihood at the iteration 9958 is: -9.440120418662984
# [[ 0.21408075  0.18560233]
#  [ 0.33673259  0.21049469]
#  [-0.45389432 -0.18566465]
#  [-0.25396507 -0.49304948]] (4, 2)
# The log likelihood at the iteration 9959 is: -9.43972740324759
# [[ 0.21406183  0.18558606]
#  [ 0.33670232  0.21047419]
#  [-0.45385361 -0.18564284]
#  [-0.25394441 -0.49301864]] (4, 2)
# The log likelihood at the iteration 9960 is: -9.439334452390616
# [[ 0.21404292  0.18556979]
#  [ 0.33667205  0.21045369]
#  [-0.45381291 -0.18562104]
#  [-0.25392375 -0.4929878 ]] (4, 2)
# The log likelihood at the iteration 9961 is: -9.438941566074751
# [[ 0.21402401  0.18555352]
#  [ 0.33664178  0.2104332 ]
#  [-0.45377221 -0.18559924]
#  [-0.2539031  -0.49295696]] (4, 2)
# The log likelihood at the iteration 9962 is: -9.438548744282716
# [[ 0.2140051   0.18553726]
#  [ 0.33661152  0.21041271]
#  [-0.45373152 -0.18557745]
#  [-0.25388245 -0.49292613]] (4, 2)
# The log likelihood at the iteration 9963 is: -9.438155986997202
# [[ 0.21398619  0.18552099]
#  [ 0.33658127  0.21039222]
#  [-0.45369083 -0.18555566]
#  [-0.2538618  -0.4928953 ]] (4, 2)
# The log likelihood at the iteration 9964 is: -9.437763294200941
# [[ 0.21396729  0.18550474]
#  [ 0.33655102  0.21037174]
#  [-0.45365016 -0.18553387]
#  [-0.25384116 -0.49286448]] (4, 2)
# The log likelihood at the iteration 9965 is: -9.437370665876658
# [[ 0.21394839  0.18548848]
#  [ 0.33652078  0.21035126]
#  [-0.45360949 -0.18551209]
#  [-0.25382052 -0.49283366]] (4, 2)
# The log likelihood at the iteration 9966 is: -9.436978102007068
# [[ 0.2139295   0.18547223]
#  [ 0.33649055  0.21033079]
#  [-0.45356883 -0.18549032]
#  [-0.25379989 -0.49280285]] (4, 2)
# The log likelihood at the iteration 9967 is: -9.43658560257493
# [[ 0.21391061  0.18545598]
#  [ 0.33646032  0.21031031]
#  [-0.45352818 -0.18546855]
#  [-0.25377926 -0.49277204]] (4, 2)
# The log likelihood at the iteration 9968 is: -9.436193167562953
# [[ 0.21389172  0.18543974]
#  [ 0.33643009  0.21028985]
#  [-0.45348753 -0.18544678]
#  [-0.25375863 -0.49274124]] (4, 2)
# The log likelihood at the iteration 9969 is: -9.43580079695392
# [[ 0.21387284  0.1854235 ]
#  [ 0.33639988  0.21026938]
#  [-0.4534469  -0.18542502]
#  [-0.25373801 -0.49271044]] (4, 2)
# The log likelihood at the iteration 9970 is: -9.435408490730573
# [[ 0.21385396  0.18540726]
#  [ 0.33636966  0.21024893]
#  [-0.45340627 -0.18540326]
#  [-0.25371739 -0.49267965]] (4, 2)
# The log likelihood at the iteration 9971 is: -9.435016248875671
# [[ 0.21383508  0.18539102]
#  [ 0.33633946  0.21022847]
#  [-0.45336565 -0.18538151]
#  [-0.25369677 -0.49264886]] (4, 2)
# The log likelihood at the iteration 9972 is: -9.434624071371982
# [[ 0.21381621  0.18537479]
#  [ 0.33630926  0.21020802]
#  [-0.45332503 -0.18535976]
#  [-0.25367616 -0.49261808]] (4, 2)
# The log likelihood at the iteration 9973 is: -9.434231958202284
# [[ 0.21379734  0.18535856]
#  [ 0.33627906  0.21018757]
#  [-0.45328442 -0.18533802]
#  [-0.25365555 -0.4925873 ]] (4, 2)
# The log likelihood at the iteration 9974 is: -9.433839909349366
# [[ 0.21377847  0.18534233]
#  [ 0.33624887  0.21016713]
#  [-0.45324383 -0.18531628]
#  [-0.25363495 -0.49255653]] (4, 2)
# The log likelihood at the iteration 9975 is: -9.43344792479599
# [[ 0.21375961  0.18532611]
#  [ 0.33621869  0.21014669]
#  [-0.45320323 -0.18529454]
#  [-0.25361435 -0.49252576]] (4, 2)
# The log likelihood at the iteration 9976 is: -9.433056004524971
# [[ 0.21374075  0.18530989]
#  [ 0.33618851  0.21012625]
#  [-0.45316265 -0.18527281]
#  [-0.25359375 -0.492495  ]] (4, 2)
# The log likelihood at the iteration 9977 is: -9.432664148519098
# [[ 0.2137219   0.18529367]
#  [ 0.33615834  0.21010582]
#  [-0.45312207 -0.18525109]
#  [-0.25357316 -0.49246424]] (4, 2)
# The log likelihood at the iteration 9978 is: -9.432272356761189
# [[ 0.21370304  0.18527746]
#  [ 0.33612817  0.21008539]
#  [-0.45308151 -0.18522937]
#  [-0.25355257 -0.49243349]] (4, 2)
# The log likelihood at the iteration 9979 is: -9.431880629234039
# [[ 0.2136842   0.18526125]
#  [ 0.33609801  0.21006496]
#  [-0.45304095 -0.18520765]
#  [-0.25353198 -0.49240275]] (4, 2)
# The log likelihood at the iteration 9980 is: -9.431488965920476
# [[ 0.21366535  0.18524504]
#  [ 0.33606785  0.21004454]
#  [-0.45300039 -0.18518594]
#  [-0.2535114  -0.492372  ]] (4, 2)
# The log likelihood at the iteration 9981 is: -9.43109736680332
# [[ 0.21364651  0.18522884]
#  [ 0.3360377   0.21002413]
#  [-0.45295985 -0.18516423]
#  [-0.25349082 -0.49234127]] (4, 2)
# The log likelihood at the iteration 9982 is: -9.430705831865408
# [[ 0.21362767  0.18521264]
#  [ 0.33600756  0.21000371]
#  [-0.45291931 -0.18514253]
#  [-0.25347025 -0.49231053]] (4, 2)
# The log likelihood at the iteration 9983 is: -9.430314361089577
# [[ 0.21360884  0.18519644]
#  [ 0.33597742  0.2099833 ]
#  [-0.45287878 -0.18512083]
#  [-0.25344968 -0.49227981]] (4, 2)
# The log likelihood at the iteration 9984 is: -9.429922954458657
# [[ 0.21359     0.18518025]
#  [ 0.33594729  0.2099629 ]
#  [-0.45283826 -0.18509913]
#  [-0.25342911 -0.49224908]] (4, 2)
# The log likelihood at the iteration 9985 is: -9.429531611955527
# [[ 0.21357118  0.18516405]
#  [ 0.33591716  0.20994249]
#  [-0.45279774 -0.18507744]
#  [-0.25340855 -0.49221837]] (4, 2)
# The log likelihood at the iteration 9986 is: -9.429140333563005
# [[ 0.21355235  0.18514787]
#  [ 0.33588704  0.2099221 ]
#  [-0.45275723 -0.18505576]
#  [-0.25338799 -0.49218766]] (4, 2)
# The log likelihood at the iteration 9987 is: -9.428749119263987
# [[ 0.21353353  0.18513168]
#  [ 0.33585693  0.2099017 ]
#  [-0.45271673 -0.18503408]
#  [-0.25336744 -0.49215695]] (4, 2)
# The log likelihood at the iteration 9988 is: -9.428357969041315
# [[ 0.21351471  0.1851155 ]
#  [ 0.33582682  0.20988131]
#  [-0.45267624 -0.1850124 ]
#  [-0.25334688 -0.49212625]] (4, 2)
# The log likelihood at the iteration 9989 is: -9.427966882877884
# [[ 0.2134959   0.18509932]
#  [ 0.33579672  0.20986092]
#  [-0.45263576 -0.18499073]
#  [-0.25332634 -0.49209555]] (4, 2)
# The log likelihood at the iteration 9990 is: -9.427575860756562
# [[ 0.21347709  0.18508314]
#  [ 0.33576662  0.20984054]
#  [-0.45259528 -0.18496906]
#  [-0.25330579 -0.49206486]] (4, 2)
# The log likelihood at the iteration 9991 is: -9.42718490266024
# [[ 0.21345828  0.18506697]
#  [ 0.33573653  0.20982016]
#  [-0.45255481 -0.1849474 ]
#  [-0.25328525 -0.49203417]] (4, 2)
# The log likelihood at the iteration 9992 is: -9.42679400857182
# [[ 0.21343948  0.1850508 ]
#  [ 0.33570644  0.20979979]
#  [-0.45251435 -0.18492574]
#  [-0.25326471 -0.49200349]] (4, 2)
# The log likelihood at the iteration 9993 is: -9.426403178474184
# [[ 0.21342068  0.18503464]
#  [ 0.33567636  0.20977942]
#  [-0.45247389 -0.18490409]
#  [-0.25324418 -0.49197281]] (4, 2)
# The log likelihood at the iteration 9994 is: -9.426012412350255
# [[ 0.21340188  0.18501847]
#  [ 0.33564628  0.20975905]
#  [-0.45243345 -0.18488244]
#  [-0.25322365 -0.49194214]] (4, 2)
# The log likelihood at the iteration 9995 is: -9.425621710182934
# [[ 0.21338309  0.18500231]
#  [ 0.33561622  0.20973868]
#  [-0.45239301 -0.18486079]
#  [-0.25320313 -0.49191147]] (4, 2)
# The log likelihood at the iteration 9996 is: -9.425231071955144
# [[ 0.2133643   0.18498616]
#  [ 0.33558615  0.20971832]
#  [-0.45235257 -0.18483915]
#  [-0.2531826  -0.49188081]] (4, 2)
# The log likelihood at the iteration 9997 is: -9.424840497649813
# [[ 0.21334552  0.18497   ]
#  [ 0.33555609  0.20969797]
#  [-0.45231215 -0.18481752]
#  [-0.25316209 -0.49185015]] (4, 2)
# The log likelihood at the iteration 9998 is: -9.424449987249865
# [[ 0.21332673  0.18495385]
#  [ 0.33552604  0.20967762]
#  [-0.45227173 -0.18479589]
#  [-0.25314157 -0.4918195 ]] (4, 2)
# The log likelihood at the iteration 9999 is: -9.424059540738243
# [[ 0.21330795  0.18493771]
#  [ 0.335496    0.20965727]
#  [-0.45223132 -0.18477426]
#  [-0.25312106 -0.49178885]] (4, 2)
# The log likelihood at the iteration 10000 is: -9.423669158097885
# The final result for the weights are:  [[ 3.0109184   3.18414226]
#  [ 5.4552686   2.03781441]
#  [-7.299706   -3.35960729]
#  [-3.65036323 -5.42628891]]

# %%
def predict(X, w, y):
    count = 0
    for i in range(len(y)):
        probability_list = []
        for k in range(K):
            probability_list.append(probability(X[i,:], w, k))
        largest_index = probability_list.index(max(probability_list))
        predicted_y = unique_labels[largest_index]
#         print("Predict the {}-th x_test as {}".format(i, predicted_y))
        if predicted_y == y[i]:
            count += 1
    accuracy = count / len(y)
    print("The accuracy of the test data is {}".format(accuracy))
    
predict(X_test, w, y_test)
# Out:
# The accuracy of the test data is 0.92

# %% [markdown]
# Now compare with the baseline: logistic regression from sklearn

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

logreg = LogisticRegression(C = 1e5)
clf = logreg.fit(X_train, y_train)
predicted_y = clf.predict(X_test)
accuracy_score(predicted_y, y_test)
# Out:
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 0.96

# %%
# Out:
# [[0.2]]
