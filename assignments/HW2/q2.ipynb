# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Load data
q2_data = np.load('q2_data/q2_data.npz')

# %%
# Extract training and test sets:
X_train = q2_data['q2x_train']
y_train = q2_data['q2y_train']
X_test = q2_data['q2x_test']
y_test = q2_data['q2y_test']

# %% [markdown]
# Check the classes of y:

# %%
unique_labels = list(set(y_train.flatten().tolist()))
print(unique_labels)
K = len(unique_labels)
print("There are {} classes for the labels.".format(K))
# Out:
# [1.0, 2.0, 3.0]
# There are 3 classes for the labels.

# %% [markdown]
# Now implement the softmax regression from pieces:

# %%
# exponentional:
def exponential(X, w_k):
    return np.exp(X.dot(w_k))


# probability:
def probability(X, w, k):
    exp_list = [exponential(X, w[:,j]) for j in range(K-1)]
    denominator = 1 + np.sum(exp_list)
    if k == K - 1:
        return 1 / denominator
    nominator = exponential(X, w[:,k])
    return nominator / denominator
    
    
# indicator function:
def indicator(y_true, m):
    if y_true == m: 
        return 1
    return 0


# log-likelihood function:
def log_likelihood(X, w, y):
    ll = 0
    for i in range(X.shape[0]):
        for k in range(K):
            if y[i] == unique_labels[k]:
                ll += np.log(probability(X[i,:], w, k))
    return ll
            
    
# gradient:
def gradient(X, w, y, k):
    l = X.shape[0]
    grad = 0
    for i in range(l):
        grad += X[i,:] * (indicator(y[i], unique_labels[k]) - probability(X[i,:], w, k))
    return grad
        

# training：
def training(X, w, y):
    alpha = 0.0005
    epsilon = 1e-10
    ll = 0
    ll_new = 1
    num_iter = 100
    curr_iter = 0
    while abs(ll - ll_new) > epsilon and curr_iter < num_iter:
        print("w:{}".format(w))
        curr_iter += 1
        ll = ll_new
        grad_matrix = np.zeros((w.shape[0], w.shape[1]))
        for k in range(K-1):
            grad_matrix[:,k] = gradient(X, w, y, k)
        print(grad_matrix, grad_matrix.shape)
        w += alpha * grad_matrix
        ll_new = log_likelihood(X, w, y)
        print("The log likelihood at the iteration {} is: {}".format(curr_iter, ll_new))
    print("The final result for the weights are: ", w)
    
        
# print(X_train.shape)
# w = np.zeros((X_train.shape[1], K - 1))
# print(w.shape)
# print(log_likelihood(X_train, w, y_train))
# training(X_train, w, y_train)

# %%
def predict(X, w, y):
    count = 0
    for i in range(len(y)):
        probability_list = []
        for k in range(K):
            probability_list.append(probability(X[i,:], w, k))
        largest_index = probability_list.index(max(probability_list))
        predicted_y = unique_labels[largest_index]
#         print("Predict the {}-th x_test as {}".format(i, predicted_y))
        if predicted_y == y[i]:
            count += 1
    accuracy = count / len(y)
    print("The accuracy of the test data is {}".format(accuracy))
    
predict(X_test, w, y_test)
# Out:
# The accuracy of the test data is 0.92

# %% [markdown]
# Now compare with the baseline: logistic regression from sklearn

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

logreg = LogisticRegression(C = 1e5)
clf = logreg.fit(X_train, y_train)
predicted_y = clf.predict(X_test)
accuracy_score(predicted_y, y_test)
# Out:
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 0.96

# %%
x=np.array([[0,7,0,4],[4,5,6,7]])
x = np.reshape(x,(4,2))
y=np.array([[1],[1],[2],[3]]) 
w = np.zeros((x.shape[1], 2))

# %%
training(x,w,y)
# Out:
# w:[[0. 0.]
#  [0. 0.]]
# [[-3.33333333  0.66666667]
#  [ 3.33333333 -2.66666667]] (2, 2)
# The log likelihood at the iteration 1 is: -4.37962132319119
# w:[[-0.00166667  0.00033333]
#  [ 0.00166667 -0.00133333]]
# [[-3.34429324  0.6830173 ]
#  [ 3.28646067 -2.61587813]] (2, 2)
# The log likelihood at the iteration 2 is: -4.365032630189109
# w:[[-0.00333881  0.00067484]
#  [ 0.0033099  -0.00264127]]
# [[-3.35463798  0.69869367]
#  [ 3.24072655 -2.56650855]] (2, 2)
# The log likelihood at the iteration 3 is: -4.350673252985281
# w:[[-0.00501613  0.00102419]
#  [ 0.00493026 -0.00392453]]
# [[-3.36438496  0.71371896]
#  [ 3.19610483 -2.51851403]] (2, 2)
# The log likelihood at the iteration 4 is: -4.336533897670807
# w:[[-0.00669832  0.00138105]
#  [ 0.00652831 -0.00518378]]
# [[-3.37355122  0.72811558]
#  [ 3.15256962 -2.47185203]] (2, 2)
# The log likelihood at the iteration 5 is: -4.322605769871098
# w:[[-0.0083851   0.00174511]
#  [ 0.0081046  -0.00641971]]
# [[-3.3821535   0.74190513]
#  [ 3.11009533 -2.42648131]] (2, 2)
# The log likelihood at the iteration 6 is: -4.308880547050919
# w:[[-0.01007618  0.00211606]
#  [ 0.00965965 -0.00763295]]
# [[-3.39020816  0.75510846]
#  [ 3.06865671 -2.38236193]] (2, 2)
# The log likelihood at the iteration 7 is: -4.295350352292889
# w:[[-0.01177128  0.00249361]
#  [ 0.01119397 -0.00882413]]
# [[-3.39773125  0.76774571]
#  [ 3.02822886 -2.3394552 ]] (2, 2)
# The log likelihood at the iteration 8 is: -4.282007729481466
# w:[[-0.01347015  0.00287749]
#  [ 0.01270809 -0.00999386]]
# [[-3.40473843  0.7798363 ]
#  [ 2.98878723 -2.29772367]] (2, 2)
# The log likelihood at the iteration 9 is: -4.268845619826115
# w:[[-0.01517252  0.0032674 ]
#  [ 0.01420248 -0.01114272]]
# [[-3.41124503  0.79139895]
#  [ 2.95030768 -2.25713106]] (2, 2)
# The log likelihood at the iteration 10 is: -4.255857339659171
# w:[[-0.01687814  0.0036631 ]
#  [ 0.01567764 -0.01227129]]
# [[-3.41726604  0.80245174]
#  [ 2.91276643 -2.21764227]] (2, 2)
# The log likelihood at the iteration 11 is: -4.24303655944587
# w:[[-0.01858677  0.00406433]
#  [ 0.01713402 -0.01338011]]
# [[-3.42281608  0.81301211]
#  [ 2.87614013 -2.1792233 ]] (2, 2)
# The log likelihood at the iteration 12 is: -4.230377283946148
# w:[[-0.02029818  0.00447084]
#  [ 0.01857209 -0.01446972]]
# [[-3.42790941  0.82309687]
#  [ 2.84040585 -2.14184127]] (2, 2)
# The log likelihood at the iteration 13 is: -4.2178738334699615
# w:[[-0.02201213  0.00488238]
#  [ 0.01999229 -0.01554064]]
# [[-3.43255998  0.83272226]
#  [ 2.80554107 -2.10546434]] (2, 2)
# The log likelihood at the iteration 14 is: -4.205520826170121
# w:[[-0.02372841  0.00529874]
#  [ 0.02139506 -0.01659337]]
# [[-3.43678137  0.84190392]
#  [ 2.77152371 -2.07006171]] (2, 2)
# The log likelihood at the iteration 15 is: -4.193313161318845
# w:[[-0.0254468   0.0057197 ]
#  [ 0.02278082 -0.0176284 ]]
# [[-3.44058682  0.85065696]
#  [ 2.73833211 -2.03560358]] (2, 2)
# The log likelihood at the iteration 16 is: -4.1812460035165175
# w:[[-0.0271671   0.00614503]
#  [ 0.02414999 -0.0186462 ]]
# [[-3.44398924  0.85899595]
#  [ 2.70594505 -2.00206109]] (2, 2)
# The log likelihood at the iteration 17 is: -4.169314767783366
# w:[[-0.02888909  0.00657452]
#  [ 0.02550296 -0.01964724]]
# [[-3.44700121  0.86693493]
#  [ 2.67434177 -1.96940636]] (2, 2)
# The log likelihood at the iteration 18 is: -4.157515105486949
# w:[[-0.03061259  0.00700799]
#  [ 0.02684013 -0.02063194]]
# [[-3.44963499  0.87448748]
#  [ 2.64350191 -1.93761237]] (2, 2)
# The log likelihood at the iteration 19 is: -4.145842891060549
# w:[[-0.03233741  0.00744523]
#  [ 0.02816188 -0.02160074]]
# [[-3.4519025   0.88166667]
#  [ 2.61340558 -1.90665302]] (2, 2)
# The log likelihood at the iteration 20 is: -4.134294209469655
# w:[[-0.03406336  0.00788607]
#  [ 0.02946859 -0.02255407]]
# [[-3.45381536  0.88848513]
#  [ 2.5840333  -1.87650303]] (2, 2)
# The log likelihood at the iteration 21 is: -4.122865344385782
# w:[[-0.03579027  0.00833031]
#  [ 0.0307606  -0.02349232]]
# [[-3.45538488  0.89495504]
#  [ 2.55536604 -1.84713795]] (2, 2)
# The log likelihood at the iteration 22 is: -4.111552767028894
# w:[[-0.03751796  0.00877779]
#  [ 0.03203829 -0.02441589]]
# [[-3.45662205  0.90108817]
#  [ 2.52738519 -1.81853413]] (2, 2)
# The log likelihood at the iteration 23 is: -4.100353125641588
# w:[[-0.03924627  0.00922833]
#  [ 0.03330198 -0.02532516]]
# [[-3.45753758  0.90689586]
#  [ 2.50007258 -1.79066868]] (2, 2)
# The log likelihood at the iteration 24 is: -4.0892632355601055
# w:[[-0.04097504  0.00968178]
#  [ 0.03455202 -0.02622049]]
# [[-3.45814187  0.91238907]
#  [ 2.47341046 -1.76351945]] (2, 2)
# The log likelihood at the iteration 25 is: -4.078280069849009
# w:[[-0.04270411  0.01013797]
#  [ 0.03578872 -0.02710225]]
# [[-3.45844506  0.91757838]
#  [ 2.44738149 -1.73706503]] (2, 2)
# The log likelihood at the iteration 26 is: -4.067400750468068
# w:[[-0.04443334  0.01059676]
#  [ 0.03701241 -0.02797079]]
# [[-3.45845698  0.92247399]
#  [ 2.42196875 -1.71128467]] (2, 2)
# The log likelihood at the iteration 27 is: -4.056622539941582
# w:[[-0.04616256  0.011058  ]
#  [ 0.0382234  -0.02882643]]
# [[-3.4581872   0.92708577]
#  [ 2.39715571 -1.68615832]] (2, 2)
# The log likelihood at the iteration 28 is: -4.045942833501929
# w:[[-0.04789166  0.01152154]
#  [ 0.03942197 -0.02966951]]
# [[-3.45764503  0.93142323]
#  [ 2.37292629 -1.66166656]] (2, 2)
# The log likelihood at the iteration 29 is: -4.035359151680625
# w:[[-0.04962048  0.01198726]
#  [ 0.04060844 -0.03050034]]
# [[-3.45683952  0.93549558]
#  [ 2.34926474 -1.6377906 ]] (2, 2)
# The log likelihood at the iteration 30 is: -4.024869133321655
# w:[[-0.0513489   0.012455  ]
#  [ 0.04178307 -0.03131924]]
# [[-3.45577943  0.93931168]
#  [ 2.32615576 -1.61451228]] (2, 2)
# The log likelihood at the iteration 31 is: -4.014470528993159
# w:[[-0.05307679  0.01292466]
#  [ 0.04294615 -0.03212649]]
# [[-3.45447332  0.94288012]
#  [ 2.3035844  -1.59181398]] (2, 2)
# The log likelihood at the iteration 32 is: -4.004161194774907
# w:[[-0.05480403  0.0133961 ]
#  [ 0.04409794 -0.0329224 ]]
# [[-3.45292948  0.94620919]
#  [ 2.28153608 -1.56967868]] (2, 2)
# The log likelihood at the iteration 33 is: -3.993939086400209
# w:[[-0.05653049  0.0138692 ]
#  [ 0.04523871 -0.03370724]]
# [[-3.45115595  0.94930689]
#  [ 2.25999663 -1.54808989]] (2, 2)
# The log likelihood at the iteration 34 is: -3.983802253732094
# w:[[-0.05825607  0.01434386]
#  [ 0.04636871 -0.03448128]]
# [[-3.44916058  0.95218095]
#  [ 2.2389522  -1.52703165]] (2, 2)
# The log likelihood at the iteration 35 is: -3.9737488355547184
# w:[[-0.05998065  0.01481995]
#  [ 0.04748818 -0.0352448 ]]
# [[-3.44695095  0.95483887]
#  [ 2.21838932 -1.50648851]] (2, 2)
# The log likelihood at the iteration 36 is: -3.9637770546620144
# w:[[-0.06170412  0.01529737]
#  [ 0.04859738 -0.03599804]]
# [[-3.44453446  0.95728786]
#  [ 2.19829486 -1.48644552]] (2, 2)
# The log likelihood at the iteration 37 is: -3.953885213226603
# w:[[-0.06342639  0.01577601]
#  [ 0.04969652 -0.03674127]]
# [[-3.44191826  0.9595349 ]
#  [ 2.17865604 -1.4668882 ]] (2, 2)
# The log likelihood at the iteration 38 is: -3.9440716884329436
# w:[[-0.06514735  0.01625578]
#  [ 0.05078585 -0.03747471]]
# [[-3.43910931  0.96158675]
#  [ 2.15946041 -1.44780251]] (2, 2)
# The log likelihood at the iteration 39 is: -3.934334928359606
# w:[[-0.06686691  0.01673657]
#  [ 0.05186558 -0.03819861]]
# [[-3.43611438  0.96344995]
#  [ 2.14069584 -1.42917489]] (2, 2)
# The log likelihood at the iteration 40 is: -3.9246734480963887
# w:[[-0.06858496  0.0172183 ]
#  [ 0.05293593 -0.0389132 ]]
# [[-3.43294002  0.96513079]
#  [ 2.12235055 -1.41099218]] (2, 2)
# The log likelihood at the iteration 41 is: -3.9150858260828376
# w:[[-0.07030143  0.01770086]
#  [ 0.05399711 -0.03961869]]
# [[-3.42959259  0.96663539]
#  [ 2.10441303 -1.39324164]] (2, 2)
# The log likelihood at the iteration 42 is: -3.9055707006554528
# w:[[-0.07201623  0.01818418]
#  [ 0.05504931 -0.04031532]]
# [[-3.42607828  0.96796965]
#  [ 2.08687212 -1.37591095]] (2, 2)
# The log likelihood at the iteration 43 is: -3.8961267667916317
# w:[[-0.07372927  0.01866816]
#  [ 0.05609275 -0.04100327]]
# [[-3.42240308  0.96913928]
#  [ 2.06971694 -1.35898815]] (2, 2)
# The log likelihood at the iteration 44 is: -3.8867527730390394
# w:[[-0.07544047  0.01915273]
#  [ 0.05712761 -0.04168276]]
# [[-3.41857282  0.9701498 ]
#  [ 2.05293689 -1.34246167]] (2, 2)
# The log likelihood at the iteration 45 is: -3.8774475186197797
# w:[[-0.07714976  0.01963781]
#  [ 0.05815408 -0.042354  ]]
# [[-3.41459313  0.97100657]
#  [ 2.03652168 -1.32632029]] (2, 2)
# The log likelihood at the iteration 46 is: -3.8682098506993077
# w:[[-0.07885705  0.02012331]
#  [ 0.05917234 -0.04301716]]
# [[-3.41046951  0.97171474]
#  [ 2.0204613  -1.31055314]] (2, 2)
# The log likelihood at the iteration 47 is: -3.8590386618106534
# w:[[-0.08056229  0.02060917]
#  [ 0.06018257 -0.04367243]]
# [[-3.40620727  0.97227933]
#  [ 2.00474599 -1.29514971]] (2, 2)
# The log likelihood at the iteration 48 is: -3.849932887425002
# w:[[-0.08226539  0.02109531]
#  [ 0.06118494 -0.04432001]]
# [[-3.40181157  0.97270517]
#  [ 1.98936627 -1.28009979]] (2, 2)
# The log likelihood at the iteration 49 is: -3.8408915036602527
# w:[[-0.0839663   0.02158166]
#  [ 0.06217962 -0.04496006]]
# [[-3.39728741  0.97299696]
#  [ 1.97431293 -1.26539349]] (2, 2)
# The log likelihood at the iteration 50 is: -3.831913525119612
# w:[[-0.08566494  0.02206816]
#  [ 0.06316678 -0.04559275]]
# [[-3.39263966  0.97315922]
#  [ 1.959577   -1.25102122]] (2, 2)
# The log likelihood at the iteration 51 is: -3.8229980028527653
# w:[[-0.08736126  0.02255474]
#  [ 0.06414657 -0.04621826]]
# [[-3.38787301  0.97319635]
#  [ 1.94514977 -1.23697371]] (2, 2)
# The log likelihood at the iteration 52 is: -3.814144022432579
# w:[[-0.0890552   0.02304134]
#  [ 0.06511914 -0.04683675]]
# [[-3.38299205  0.97311261]
#  [ 1.93102274 -1.22324195]] (2, 2)
# The log likelihood at the iteration 53 is: -3.8053507021407014
# w:[[-0.09074669  0.02352789]
#  [ 0.06608465 -0.04744837]]
# [[-3.37800119  0.9729121 ]
#  [ 1.91718769 -1.20981722]] (2, 2)
# The log likelihood at the iteration 54 is: -3.796617191255812
# w:[[-0.09243569  0.02401435]
#  [ 0.06704325 -0.04805328]]
# [[-3.37290475  0.97259881]
#  [ 1.9036366  -1.19669104]] (2, 2)
# The log likelihood at the iteration 55 is: -3.787942668438623
# w:[[-0.09412215  0.02450065]
#  [ 0.06799507 -0.04865163]]
# [[-3.36770688  0.97217661]
#  [ 1.89036169 -1.18385523]] (2, 2)
# The log likelihood at the iteration 56 is: -3.7793263402080868
# w:[[-0.095806    0.02498674]
#  [ 0.06894025 -0.04924355]]
# [[-3.36241163  0.97164922]
#  [ 1.87735537 -1.17130181]] (2, 2)
# The log likelihood at the iteration 57 is: -3.770767439503568
# w:[[-0.09748721  0.02547256]
#  [ 0.06987892 -0.0498292 ]]
# [[-3.35702292  0.97102027]
#  [ 1.86461029 -1.15902309]] (2, 2)
# The log likelihood at the iteration 58 is: -3.7622652243280568
# w:[[-0.09916572  0.02595807]
#  [ 0.07081123 -0.05040872]]
# [[-3.35154455  0.97029327]
#  [ 1.8521193  -1.14701157]] (2, 2)
# The log likelihood at the iteration 59 is: -3.7538189764677696
# w:[[-0.10084149  0.02644322]
#  [ 0.07173729 -0.05098222]]
# [[-3.3459802   0.96947161]
#  [ 1.83987544 -1.13526   ]] (2, 2)
# The log likelihood at the iteration 60 is: -3.745428000283769
# w:[[-0.10251448  0.02692796]
#  [ 0.07265723 -0.05154985]]
# [[-3.34033344  0.96855858]
#  [ 1.82787197 -1.12376135]] (2, 2)
# The log likelihood at the iteration 61 is: -3.7370916215714627
# w:[[-0.10418465  0.02741223]
#  [ 0.07357116 -0.05211173]]
# [[-3.33460775  0.96755737]
#  [ 1.8161023  -1.11250878]] (2, 2)
# The log likelihood at the iteration 62 is: -3.728809186484107
# w:[[-0.10585195  0.02789601]
#  [ 0.07447921 -0.05266799]]
# [[-3.32880647  0.96647107]
#  [ 1.80456008 -1.10149568]] (2, 2)
# The log likelihood at the iteration 63 is: -3.7205800605166335
# w:[[-0.10751635  0.02837925]
#  [ 0.07538149 -0.05321874]]
# [[-3.32293286  0.96530267]
#  [ 1.79323909 -1.09071562]] (2, 2)
# The log likelihood at the iteration 64 is: -3.7124036275463688
# w:[[-0.10917782  0.0288619 ]
#  [ 0.07627811 -0.05376409]]
# [[-3.31699008  0.96405508]
#  [ 1.78213331 -1.08016236]] (2, 2)
# The log likelihood at the iteration 65 is: -3.7042792889273723
# w:[[-0.11083631  0.02934393]
#  [ 0.07716918 -0.05430417]]
# [[-3.31098118  0.9627311 ]
#  [ 1.7712369  -1.06982986]] (2, 2)
# The log likelihood at the iteration 66 is: -3.6962064626353324
# w:[[-0.11249181  0.02982529]
#  [ 0.0780548  -0.05483909]]
# [[-3.30490913  0.96133345]
#  [ 1.76054416 -1.05971224]] (2, 2)
# The log likelihood at the iteration 67 is: -3.68818458246014
# w:[[-0.11414426  0.03030596]
#  [ 0.07893507 -0.05536895]]
# [[-3.29877679  0.95986478]
#  [ 1.75004958 -1.0498038 ]] (2, 2)
# The log likelihood at the iteration 68 is: -3.6802130972434024
# w:[[-0.11579365  0.03078589]
#  [ 0.0798101  -0.05589385]]
# [[-3.29258695  0.95832764]
#  [ 1.73974779 -1.04009903]] (2, 2)
# The log likelihood at the iteration 69 is: -3.6722914701583402
# w:[[-0.11743994  0.03126506]
#  [ 0.08067997 -0.0564139 ]]
# [[-3.28634231  0.95672452]
#  [ 1.72963357 -1.03059254]] (2, 2)
# The log likelihood at the iteration 70 is: -3.6644191780296427
# w:[[-0.11908311  0.03174342]
#  [ 0.08154479 -0.05692919]]
# [[-3.28004548  0.95505782]
#  [ 1.71970186 -1.02127913]] (2, 2)
# The log likelihood at the iteration 71 is: -3.656595710691011
# w:[[-0.12072314  0.03222095]
#  [ 0.08240464 -0.05743983]]
# [[-3.27369899  0.95332988]
#  [ 1.70994774 -1.01215374]] (2, 2)
# The log likelihood at the iteration 72 is: -3.6488205703782284
# w:[[-0.12235999  0.03269761]
#  [ 0.08325961 -0.05794591]]
# [[-3.2673053   0.95154294]
#  [ 1.70036644 -1.00321146]] (2, 2)
# The log likelihood at the iteration 73 is: -3.6410932711557393
# w:[[-0.12399364  0.03317338]
#  [ 0.08410979 -0.05844751]]
# [[-3.26086677  0.9496992 ]
#  [ 1.69095332 -0.99444753]] (2, 2)
# The log likelihood at the iteration 74 is: -3.633413338374837
# w:[[-0.12562407  0.03364823]
#  [ 0.08495527 -0.05894474]]
# [[-3.25438571  0.94780079]
#  [ 1.68170387 -0.98585731]] (2, 2)
# The log likelihood at the iteration 75 is: -3.625780308161645
# w:[[-0.12725126  0.03412213]
#  [ 0.08579612 -0.05943767]]
# [[-3.24786435  0.94584977]
#  [ 1.67261371 -0.97743631]] (2, 2)
# The log likelihood at the iteration 76 is: -3.6181937269332045
# w:[[-0.1288752   0.03459506]
#  [ 0.08663243 -0.05992639]]
# [[-3.24130484  0.94384813]
#  [ 1.66367859 -0.96918016]] (2, 2)
# The log likelihood at the iteration 77 is: -3.610653150940079
# w:[[-0.13049585  0.03506698]
#  [ 0.08746427 -0.06041098]]
# [[-3.23470929  0.94179781]
#  [ 1.65489439 -0.96108462]] (2, 2)
# The log likelihood at the iteration 78 is: -3.6031581458339517
# w:[[-0.1321132   0.03553788]
#  [ 0.08829172 -0.06089152]]
# [[-3.2280797   0.93970069]
#  [ 1.64625708 -0.95314557]] (2, 2)
# The log likelihood at the iteration 79 is: -3.595708286258811
# w:[[-0.13372724  0.03600773]
#  [ 0.08911484 -0.06136809]]
# [[-3.22141805  0.93755858]
#  [ 1.63776278 -0.94535902]] (2, 2)
# The log likelihood at the iteration 80 is: -3.5883031554643816
# w:[[-0.13533795  0.03647651]
#  [ 0.08993373 -0.06184077]]
# [[-3.21472623  0.93537327]
#  [ 1.62940771 -0.93772107]] (2, 2)
# The log likelihood at the iteration 81 is: -3.580942344940535
# w:[[-0.13694532  0.0369442 ]
#  [ 0.09074843 -0.06230963]]
# [[-3.20800608  0.93314645]
#  [ 1.62118819 -0.93022796]] (2, 2)
# The log likelihood at the iteration 82 is: -3.5736254540714962
# w:[[-0.13854932  0.03741077]
#  [ 0.09155902 -0.06277474]]
# [[-3.20125937  0.93087978]
#  [ 1.61310066 -0.922876  ]] (2, 2)
# The log likelihood at the iteration 83 is: -3.5663520898087215
# w:[[-0.14014995  0.03787621]
#  [ 0.09236557 -0.06323618]]
# [[-3.19448783  0.92857489]
#  [ 1.60514165 -0.91566165]] (2, 2)
# The log likelihood at the iteration 84 is: -3.5591218663613975
# w:[[-0.14174719  0.0383405 ]
#  [ 0.09316815 -0.06369401]]
# [[-3.18769313  0.92623334]
#  [ 1.5973078  -0.90858143]] (2, 2)
# The log likelihood at the iteration 85 is: -3.5519344049035557
# w:[[-0.14334104  0.03880362]
#  [ 0.0939668  -0.0641483 ]]
# [[-3.18087688  0.92385663]
#  [ 1.58959585 -0.90163198]] (2, 2)
# The log likelihood at the iteration 86 is: -3.5447893332968645
# w:[[-0.14493148  0.03926554]
#  [ 0.0947616  -0.06459912]]
# [[-3.17404064  0.92144624]
#  [ 1.58200262 -0.89481003]] (2, 2)
# The log likelihood at the iteration 87 is: -3.537686285828227
# w:[[-0.1465185   0.03972627]
#  [ 0.0955526  -0.06504653]]
# [[-3.16718592  0.91900359]
#  [ 1.57452503 -0.8881124 ]] (2, 2)
# The log likelihood at the iteration 88 is: -3.530624902961327
# w:[[-0.14810209  0.04018577]
#  [ 0.09633986 -0.06549058]]
# [[-3.16031419  0.91653008]
#  [ 1.5671601  -0.88153601]] (2, 2)
# The log likelihood at the iteration 89 is: -3.5236048311013555
# w:[[-0.14968225  0.04064403]
#  [ 0.09712344 -0.06593135]]
# [[-3.15342685  0.91402703]
#  [ 1.55990491 -0.87507783]] (2, 2)
# The log likelihood at the iteration 90 is: -3.516625722372167
# w:[[-0.15125896  0.04110105]
#  [ 0.09790339 -0.06636889]]
# [[-3.14652527  0.91149575]
#  [ 1.55275666 -0.86873497]] (2, 2)
# The log likelihood at the iteration 91 is: -3.5096872344051624
# w:[[-0.15283222  0.04155679]
#  [ 0.09867977 -0.06680326]]
# [[-3.13961078  0.90893751]
#  [ 1.5457126  -0.86250458]] (2, 2)
# The log likelihood at the iteration 92 is: -3.502789030139251
# w:[[-0.15440203  0.04201126]
#  [ 0.09945263 -0.06723451]]
# [[-3.13268466  0.90635352]
#  [ 1.53877007 -0.85638389]] (2, 2)
# The log likelihood at the iteration 93 is: -3.4959307776312505
# w:[[-0.15596837  0.04246444]
#  [ 0.10022201 -0.0676627 ]]
# [[-3.12574815  0.90374498]
#  [ 1.5319265  -0.85037023]] (2, 2)
# The log likelihood at the iteration 94 is: -3.4891121498761613
# w:[[-0.15753125  0.04291631]
#  [ 0.10098798 -0.06808789]]
# [[-3.11880244  0.90111303]
#  [ 1.52517938 -0.84446099]] (2, 2)
# The log likelihood at the iteration 95 is: -3.482332824636738
# w:[[-0.15909065  0.04336687]
#  [ 0.10175057 -0.06851012]]
# [[-3.11184869  0.8984588 ]
#  [ 1.51852627 -0.83865363]] (2, 2)
# The log likelihood at the iteration 96 is: -3.4755924842818553
# w:[[-0.16064657  0.0438161 ]
#  [ 0.10250983 -0.06892944]]
# [[-3.10488801  0.89578336]
#  [ 1.51196481 -0.83294567]] (2, 2)
# The log likelihood at the iteration 97 is: -3.4688908156331673
# w:[[-0.16219901  0.04426399]
#  [ 0.10326581 -0.06934592]]
# [[-3.0979215   0.89308777]
#  [ 1.5054927  -0.82733474]] (2, 2)
# The log likelihood at the iteration 98 is: -3.462227509819595
# w:[[-0.16374798  0.04471053]
#  [ 0.10401856 -0.06975958]]
# [[-3.09095019  0.89037306]
#  [ 1.49910773 -0.82181847]] (2, 2)
# The log likelihood at the iteration 99 is: -3.4556022621392097
# w:[[-0.16529345  0.04515572]
#  [ 0.10476811 -0.07017049]]
# [[-3.08397509  0.88764019]
#  [ 1.49280772 -0.81639462]] (2, 2)
# The log likelihood at the iteration 100 is: -3.4490147719280935
# The final result for the weights are:  [[-0.16683544  0.04559954]
#  [ 0.10551452 -0.07057869]]
